# %%
import torch.optim as optim
import glob
import json
import argparse
import os
import random
import math
from time import gmtime, strftime
#from models import *
#from dataset_GBU import FeatDataLayer, DATA_LOADER
#from utils import *
from sklearn.metrics.pairwise import cosine_similarity
import torch.backends.cudnn as cudnn
#import classifier
import numpy as np
import scipy.io as sio
from sklearn import preprocessing
import torch

# %%
dataset_name ='AWA2' ## dataset: CUB, AWA2, APY, FLO, SUN # (default: SUN)
dataroot = 'C:/Sushree/Jio_Institute/Dataset/SDGZSL_data' ## path to dataset

workers = 1 ## number of data loading workers # type = int (default=1)

image_embedding ='res101' ##(default) # type = str
class_embedding ='att' ##(default) # type = str

gen_nepoch = 400 ## number of epochs to train for # type = int (default = 400) 
lr = 0.0001 ## learning rate to train generater #type = float (default=0.0001) 

zsl = False ## Evaluate ZSL or GZSL # type = bool (default=False) 
finetune = False ## Use fine-tuned feature # type = bool (default = False)
ga = 15 ## relationNet weight # type = float (default = 15)
beta = 1 ## tc weight # type = float (default = 1)
weight_decay = 1e-6 ## weight_decay # type = float (default = 1e-6)
dis = 3 ## Discriminator weight # type = float (default = 3)
dis_step = 2 ## Discriminator update interval # type = float (default = 2)
kl_warmup = 0.01 ## kl warm-up for VAE # type = float (default = 0.01)
tc_warmup = 0.001 ## tc warm-up # type = float (default = 0.001)

vae_dec_drop = 0.5 #', type=float, default=0.5, help='dropout rate in the VAE decoder')
vae_enc_drop = 0.4#', type=float, default=0.4, help='dropout rate in the VAE encoder')
ae_drop = 0.2#', type=float, default=0.2, help='dropout rate in the auto-encoder')

classifier_lr = 0.001#', type=float, default=0.001, help='learning rate to train softmax classifier')
classifier_steps = 50#', type=int, default=50, help='training steps of the classifier')

batchsize = 64#', type=int, default=64, help='input batch size')
nSample = 1200#', type=int, default=1200, help='number features to generate per class')

disp_interval = 200#', type=int, default=200)
save_interval = 10000#', type=int, default=10000)
evl_interval = 400#',  type=int, default=400)
evl_start = 0#',  type=int, default=0)
manualSeed = 5606#', type=int, default=5606, help='manual seed')

latent_dim = 20#', type=int, default=20, help='dimention of latent z')
q_z_nn_output_dim = 128#', type=int, default=128, help='dimention of hidden layer in encoder')
S_dim = 1024#', type=int, default=1024)
NS_dim = 1024#', type=int, default=1024)

#parser.add_argument('--gpu', default='0', type=str, help='index of GPU to use')
#opt = parser.parse_args()

if manualSeed is None:
    manualSeed = random.randint(1, 10000)
print("Random Seed: ", manualSeed)

np.random.seed(manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
torch.cuda.manual_seed_all(manualSeed)

cudnn.benchmark = True
print('Running parameters:')
#print(json.dumps(vars(opt), indent=4, separators=(',', ': ')))
#opt.gpu = torch.device("cuda:"+opt.gpu if torch.cuda.is_available() else "cpu")
# Out:
# Random Seed:  5606
# Running parameters:

# %%
def map_label(label, classes):
    mapped_label = torch.LongTensor(label.size())
    for i in range(classes.size(0)):
        mapped_label[label == classes[i]] = i
    return mapped_label

# %%
class DATA_LOADER():
    def __init__(self, finetune, dataset_name, dataroot, class_embedding, image_embedding):
        self.finetune = finetune
        
        if dataset_name in ['FLO_EPGN','CUB_STC']:
            if self.finetune:
                self.read_fine_tune(dataset_name, dataroot, class_embedding, image_embedding)
            else:
                self.read(dataset_name, dataroot)
        elif dataset_name in ['CUB', 'AWA2', 'APY', 'FLO', 'SUN']:
            self.read_matdataset(dataroot, dataset_name, image_embedding, class_embedding)
            
        self.index_in_epoch = 0
        self.epochs_completed = 0
        self.feature_dim = self.train_feature.shape[1]
        self.att_dim = self.attribute.shape[1]
        self.text_dim = self.att_dim
        self.tr_cls_centroid = np.zeros([self.seenclasses.shape[0], self.feature_dim], np.float32)
        
        for i in range(self.seenclasses.shape[0]):
            self.tr_cls_centroid[i] = np.mean(self.train_feature[self.train_label == i].numpy(), axis=0)

    def read_fine_tune(self, dataset_name, dataroot, class_embedding, image_embedding):
        if dataset_name == "CUB_STC":
            dataset_name = "CUB"
        if dataset_name == "FLO_EPGN":
            dataset_name = "FLO"

        # matcontent = sio.loadmat(opt.dataroot + "/" + opt.dataset + "/" + opt.image_embedding + ".mat")
        # feature = matcontent['features'].T
        # label = matcontent['labels'].astype(int).squeeze() - 1
        matcontent = sio.loadmat(dataroot + "/" + dataset_name + "/" + class_embedding + "_splits.mat")
        trainval_loc = matcontent['trainval_loc'].squeeze() - 1
        train_loc = matcontent['train_loc'].squeeze() - 1
        val_unseen_loc = matcontent['val_loc'].squeeze() - 1
        test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
        test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1
        self.attribute = torch.from_numpy(matcontent['att'].T).float()
        # matcontent = sio.loadmat(opt.dataroot + "/" + opt.dataset + "/cub_feat.mat")
        matcontent = sio.loadmat(dataroot + "/" + dataset_name + "/" + image_embedding + "_finetuned.mat")

        feature = matcontent['features'].T
        label = matcontent['labels'].astype(int).squeeze() - 1
        # feature = matcontent['features'].T
        matcontent = sio.loadmat(dataroot + "/" + dataset_name + "/data.mat")
        # feature = matcontent['features'].T
        # label = matcontent['labels'].astype(int).squeeze() - 1
        train_att = matcontent['att_train']
        seen_pro = matcontent['seen_pro']
        attribute = matcontent['attribute']
        unseen_pro = matcontent['unseen_pro']
        self.attribute = torch.from_numpy(attribute).float()
        self.train_att = seen_pro.astype(np.float32)
        self.test_att = unseen_pro.astype(np.float32)

        scaler = preprocessing.MinMaxScaler()
        _train_feature = scaler.fit_transform(feature[trainval_loc])
        _test_seen_feature = scaler.transform(feature[test_seen_loc])
        _test_unseen_feature = scaler.transform(feature[test_unseen_loc])
        self.train_feature = torch.from_numpy(_train_feature).float()
        mx = self.train_feature.max()
        self.train_feature.mul_(1 / mx)
        self.train_label = torch.from_numpy(label[trainval_loc]).long()
        self.test_unseen_feature = torch.from_numpy(_test_unseen_feature).float()
        self.test_unseen_feature.mul_(1 / mx)
        self.test_unseen_label = torch.from_numpy(label[test_unseen_loc]).long()
        self.test_seen_feature = torch.from_numpy(_test_seen_feature).float()
        self.test_seen_feature.mul_(1 / mx)
        self.test_seen_label = torch.from_numpy(label[test_seen_loc]).long()

        self.seenclasses = torch.from_numpy(np.unique(self.train_label.numpy()))
        self.unseenclasses = torch.from_numpy(np.unique(self.test_unseen_label.numpy()))
        self.ntrain = self.train_feature.size()[0]
        self.ntrain_class = self.seenclasses.size(0)
        self.ntest_class = self.unseenclasses.size(0)
        self.train_class = self.seenclasses.clone()
        self.allclasses = torch.arange(0, self.ntrain_class + self.ntest_class).long()

        self.train_label = map_label(self.train_label, self.seenclasses)
        self.test_unseen_label = map_label(self.test_unseen_label, self.unseenclasses)
        self.test_seen_label = map_label(self.test_seen_label, self.seenclasses)

        self.train_att = self.attribute[self.seenclasses].numpy()
        self.test_att = self.attribute[self.unseenclasses].numpy()

    def read(self, dataset_name, dataroot):
        if dataset_name == "CUB_STC":
            dataset_name = "CUB"
        if dataset_name == "FLO_EPGN":
            dataset_name = "FLO"

        matcontent = sio.loadmat(dataroot + "/" + dataset_name + "/data.mat")
        train_att = matcontent['att_train']
        seen_pro = matcontent['seen_pro']
        attribute = matcontent['attribute']
        unseen_pro = matcontent['unseen_pro']
        self.attribute = torch.from_numpy(attribute).float()
        self.train_att = seen_pro.astype(np.float32)
        self.test_att = unseen_pro.astype(np.float32)

        train_fea = matcontent['train_fea']
        test_seen_fea = matcontent['test_seen_fea']
        test_unseen_fea = matcontent['test_unseen_fea']

        scaler = preprocessing.MinMaxScaler()
        _train_feature = scaler.fit_transform(train_fea)
        _test_seen_feature = scaler.transform(test_seen_fea)
        _test_unseen_feature = scaler.transform(test_unseen_fea)
        mx = _train_feature.max()
        train_fea = train_fea * (1 / mx)
        test_seen_fea = test_seen_fea * (1 / mx)
        test_unseen_fea = test_unseen_fea * (1 / mx)

        self.train_feature = torch.from_numpy(train_fea).float()
        self.test_seen_feature = torch.from_numpy(test_seen_fea).float()
        self.test_unseen_feature = torch.from_numpy(test_unseen_fea).float()

        matcontent = sio.loadmat(dataroot + "/" + dataset_name + "/label.mat")

        train_idx = matcontent['train_idx'] - 1
        train_label = matcontent['train_label_new']
        test_unseen_idex = matcontent['test_unseen_idex'] - 1
        test_seen_idex = matcontent['test_seen_idex'] - 1
        self.train_label = torch.from_numpy(train_idx.squeeze()).long()
        self.test_seen_label = torch.from_numpy(test_seen_idex.squeeze()).long()
        self.test_unseen_label = torch.from_numpy(test_unseen_idex.squeeze()).long()

        self.seenclasses = torch.from_numpy(np.unique(self.test_seen_label.numpy()))
        self.unseenclasses = torch.from_numpy(np.unique(self.test_unseen_label.numpy()))
        self.ntrain = self.train_feature.size()[0]
        self.ntrain_class = self.seenclasses.size(0)
        self.ntest_class = self.unseenclasses.size(0)
        self.train_class = self.seenclasses.clone()
        self.allclasses = torch.arange(0, self.ntrain_class + self.ntest_class).long()

        self.test_unseen_label = map_label(self.test_unseen_label, self.unseenclasses)
        self.test_seen_label = map_label(self.test_seen_label, self.seenclasses)

    def read_matdataset(self, dataroot, dataset_name, image_embedding, class_embedding):


        matcontent = sio.loadmat(dataroot + "/" + dataset_name + "/" + image_embedding + ".mat")
        label = matcontent['labels'].astype(int).squeeze() - 1
        if self.finetune:
            matcontent = sio.loadmat(dataroot + "/" + dataset_name + "/" + image_embedding + "_finetuned.mat")
            # label = matcontent['labels'].astype(int).squeeze() - 1

        feature = matcontent['features'].T
        if dataset_name == "APY" and self.finetune:
            feature = feature.T
        matcontent = sio.loadmat(dataroot + "/" + dataset_name + "/" + class_embedding + "_splits.mat")
        trainval_loc = matcontent['trainval_loc'].squeeze() - 1
        train_loc = matcontent['train_loc'].squeeze() - 1
        val_unseen_loc = matcontent['val_loc'].squeeze() - 1
        test_seen_loc = matcontent['test_seen_loc'].squeeze() - 1
        test_unseen_loc = matcontent['test_unseen_loc'].squeeze() - 1
        self.attribute = torch.from_numpy(matcontent['att'].T).float()
        # if opt.dataset == "FLO":
        #     temp_norm = torch.norm(self.attribute, p=2, dim=1).unsqueeze(1).expand_as(self.attribute)
        #     self.attribute = self.attribute.div(temp_norm + 1e-5)

        #
        #
        # matcontent = sio.loadmat(opt.dataroot + "/" + opt.dataset + "/data.mat")
        #
        # train_att = matcontent['att_train']
        # seen_pro = matcontent['seen_pro']
        # attribute = matcontent['attribute']
        # unseen_pro = matcontent['unseen_pro']
        # self.attribute = torch.from_numpy(attribute).float()
        # self.train_att = seen_pro.astype(np.float32)
        # self.test_att = unseen_pro.astype(np.float32)

        scaler = preprocessing.MinMaxScaler()
        _train_feature = scaler.fit_transform(feature[trainval_loc])
        _test_seen_feature = scaler.transform(feature[test_seen_loc])
        _test_unseen_feature = scaler.transform(feature[test_unseen_loc])
        self.train_feature = torch.from_numpy(_train_feature).float()
        mx = self.train_feature.max()
        self.train_feature.mul_(1 / mx)
        self.train_label = torch.from_numpy(label[trainval_loc]).long()
        self.test_unseen_feature = torch.from_numpy(_test_unseen_feature).float()
        self.test_unseen_feature.mul_(1 / mx)
        self.test_unseen_label = torch.from_numpy(label[test_unseen_loc]).long()
        self.test_seen_feature = torch.from_numpy(_test_seen_feature).float()
        self.test_seen_feature.mul_(1 / mx)
        self.test_seen_label = torch.from_numpy(label[test_seen_loc]).long()

        self.seenclasses = torch.from_numpy(np.unique(self.train_label.numpy()))
        self.unseenclasses = torch.from_numpy(np.unique(self.test_unseen_label.numpy()))
        self.ntrain = self.train_feature.size()[0]
        self.ntrain_class = self.seenclasses.size(0)
        self.ntest_class = self.unseenclasses.size(0)
        self.train_class = self.seenclasses.clone()
        self.allclasses = torch.arange(0, self.ntrain_class + self.ntest_class).long()

        self.train_label = map_label(self.train_label, self.seenclasses)
        self.test_unseen_label = map_label(self.test_unseen_label, self.unseenclasses)
        self.test_seen_label = map_label(self.test_seen_label, self.seenclasses)

        self.train_att = self.attribute[self.seenclasses].numpy()
        self.test_att = self.attribute[self.unseenclasses].numpy()

# %%
class FeatDataLayer():
    def __init__(self, label, feat_data, batchsize):
        """Set the roidb to be used by this layer during training."""
        assert len(label) == feat_data.shape[0]
        #self._opt = opt
        self._feat_data = feat_data
        self._label = label
        self._shuffle_roidb_inds()
        self._epoch = 0
        self.batchsize = batchsize

    def _shuffle_roidb_inds(self):
        """Randomly permute the training roidb."""
        self._perm = np.random.permutation(np.arange(len(self._label)))
        self._cur = 0

    def _get_next_minibatch_inds(self):
        """Return the roidb indices for the next minibatch."""
        if self._cur + self.batchsize >= len(self._label):
            self._shuffle_roidb_inds()
            self._epoch += 1

        db_inds = self._perm[self._cur:self._cur + self.batchsize]
        self._cur += self.batchsize

        return db_inds

    def forward(self):
        new_epoch = False
        if self._cur + self.batchsize >= len(self._label):
            self._shuffle_roidb_inds()
            self._epoch += 1
            new_epoch = True

        db_inds = self._perm[self._cur:self._cur + self.batchsize]
        self._cur += self.batchsize

        minibatch_feat = np.array([self._feat_data[i] for i in db_inds])
        minibatch_label = np.array([self._label[i] for i in db_inds])
        blobs = {'data': minibatch_feat, 'labels': minibatch_label, 'newEpoch': new_epoch, 'idx': db_inds}
        return blobs

    def get_whole_data(self):
        blobs = {'data': self._feat_data, 'labels': self._label}
        return blobs

# %%
from __future__ import print_function
import torch
import torch.nn as nn
from torch.autograd import Variable

class VAE(nn.Module):
    def __init__(self, Z_dim, S_dim, q_z_nn_output_dim, X_dim, C_dim, vae_enc_drop, vae_dec_drop):
        super(VAE, self).__init__()
        self.z_size = Z_dim
        self.input_size = S_dim
        #self.args = args
        self.q_z_nn_output_dim = q_z_nn_output_dim
        self.X_dim = X_dim
        self.C_dim = C_dim
        self.vae_enc_drop = vae_enc_drop
        self.vae_dec_drop = vae_dec_drop
        self.q_z_nn, self.q_z_mean, self.q_z_var = self.create_encoder()
        self.p_x_nn, self.p_x_mean = self.create_decoder()
        self.FloatTensor = torch.FloatTensor

    def create_encoder(self):
        q_z_nn = nn.Sequential(
            nn.Linear(self.X_dim + self.C_dim, 2048),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(2048, 2048),
            nn.Dropout(self.vae_enc_drop),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(2048, self.q_z_nn_output_dim)
        )
        q_z_mean = nn.Linear(self.q_z_nn_output_dim, self.z_size)

        q_z_var = nn.Sequential(
            nn.Linear(self.q_z_nn_output_dim, self.z_size),
            nn.Dropout(0.2),
            nn.Softplus(),
        )
        return q_z_nn, q_z_mean, q_z_var


    def create_decoder(self):
        p_x_nn = nn.Sequential(
            nn.Linear(self.z_size + self.C_dim, 2048),
            nn.Dropout(self.vae_dec_drop),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(2048, 2048),
            nn.BatchNorm1d(2048, 0.8),
            nn.Dropout(self.vae_dec_drop),
            nn.Linear(2048, 2048),
            nn.BatchNorm1d(2048, 0.8),
            nn.Dropout(self.vae_dec_drop),
            nn.LeakyReLU(0.2, inplace=True)
        )
        p_x_mean = nn.Sequential(
            nn.Linear(2048, self.X_dim),
            nn.LeakyReLU(0.2, inplace=True)
        )
        return p_x_nn, p_x_mean


    def reparameterize(self, mu, var):
        std = var.sqrt()
        eps = self.FloatTensor(std.size()).normal_()#.to(self.gpu)
        eps = Variable(eps)
        z = eps.mul(std).add_(mu)
        return z

    def encode(self, x, c):
        input = torch.cat((x,c),1)
        h = self.q_z_nn(input)
        h = h.view(h.size(0), -1)
        mean = self.q_z_mean(h)
        var = self.q_z_var(h)
        return mean, var

    def decode(self, z, c):
        input = torch.cat((z, c), 1)
        h = self.p_x_nn(input)
        x_mean = self.p_x_mean(h)
        return x_mean

    def forward(self, x, c, weights=None):
        z_mu, z_var = self.encode(x, c)
        z = self.reparameterize(z_mu, z_var)
        x_mean = self.decode(z, c)
        return x_mean, z_mu, z_var, z

# %%
class Classifier(nn.Module):
    def __init__(self, S_dim, dataset):
        super(Classifier, self).__init__()
        self.cls = nn.Linear(S_dim, dataset.ntrain_class) #FLO 82
        self.logic = nn.LogSoftmax(dim=1)

    def forward(self, s):
        return self.logic(self.cls(s))

# %%
class AE(nn.Module):
    def __init__(self, X_dim, S_dim, NS_dim, ae_drop):
        super(AE, self).__init__()
        #self.args = args
        self.encoder = nn.Sequential(
            nn.Linear(X_dim, S_dim + NS_dim),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(ae_drop)
        )
        self.decoder = nn.Sequential(
            nn.Linear(S_dim + NS_dim, 2048),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(ae_drop),
            nn.Linear(2048, X_dim),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(ae_drop),
        )

    def forward(self, x):
        self.S_dim = S_dim
        z = self.encoder(x)
        s = z[:, :self.S_dim]
        ns = z[:, self.S_dim:]
        x1 = self.decoder(z)
        return x1, z, s, ns

# %%
class RelationNet(nn.Module):
    def __init__(self, C_dim, S_dim):
        super(RelationNet, self).__init__()
        self.fc1 = nn.Linear(C_dim + S_dim, 2048)
        self.fc2 = nn.Linear(2048, 1)

    def forward(self, s, c):

        c_ext = c.unsqueeze(0).repeat(s.shape[0], 1, 1)
        cls_num = c_ext.shape[1]

        s_ext = torch.transpose(s.unsqueeze(0).repeat(cls_num, 1, 1), 0, 1)
        relation_pairs = torch.cat((s_ext, c_ext), 2).view(-1, c.shape[1] + s.shape[1])
        relation = nn.ReLU()(self.fc1(relation_pairs))
        relation = nn.Sigmoid()(self.fc2(relation))
        return relation

# %%
class Discriminator(nn.Module):
    def __init__(self, S_dim):
        super(Discriminator, self).__init__()
        self.fc1 = nn.Linear(S_dim*2, 2)

    def forward(self, s):
        score = self.fc1(s)
        return nn.Sigmoid()(score)

# %%
import torch.nn.init as init
import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import torch.nn.functional as F
import torch.nn as nn

# %%
def permute_dims(hs,hn):
    assert hs.dim() == 2
    assert hn.dim() == 2

    B, _ = hs.size()

    perm = torch.randperm(B).to(hs.device)
    perm_hs= hs[perm]
    perm = torch.randperm(B).to(hs.device)
    perm_hn= hn[perm]

    return perm_hs, perm_hn

# %%
class Result(object):
    def __init__(self):
        self.best_acc = 0.0
        self.best_iter = 0.0
        self.best_acc_S_T = 0.0
        self.best_acc_U_T = 0.0
        self.acc_list = []
        self.iter_list = []
        self.save_model = False

    def update(self, it, acc):
        self.acc_list += [acc]
        self.iter_list += [it]
        self.save_model = False
        if acc > self.best_acc:
            self.best_acc = acc
            self.best_iter = it
            self.save_model = True

    def update_gzsl(self, it, acc_u, acc_s, H):
        self.acc_list += [H]
        self.iter_list += [it]
        self.save_model = False
        if H > self.best_acc:
            self.best_acc = H
            self.best_iter = it
            self.best_acc_U_T = acc_u
            self.best_acc_S_T = acc_s
            self.save_model = True

# %%
def multinomial_loss_function(x_logit, x, z_mu, z_var, z, beta=1.):

    """
    Computes the cross entropy loss function while summing over batch dimension, not averaged!
    :param x_logit: shape: (batch_size, num_classes * num_channels, pixel_width, pixel_height), real valued logits
    :param x: shape (batchsize, num_channels, pixel_width, pixel_height), pixel values rescaled between [0, 1].
    :param z_mu: mean of z_0
    :param z_var: variance of z_0
    :param z_0: first stochastic latent variable
    :param z_k: last stochastic latent variable
    :param ldj: log det jacobian
    :param args: global parameter settings
    :param beta: beta for kl loss
    :return: loss, ce, kl
    """

    batch_size = x.size(0)
    target = x
    ce = nn.MSELoss(reduction='sum')(x_logit, target)
    kl = - (0.5 * torch.sum(1 + z_var.log() - z_mu.pow(2) - z_var.log().exp()))
    loss = ce + beta * kl
    loss = loss / float(batch_size)
    ce = ce / float(batch_size)
    kl = kl / float(batch_size)

    return loss, ce, kl

# %%
def synthesize_feature_test(netG, ae, dataset, nSample, S_dim, Z_dim):
    gen_feat = torch.FloatTensor(dataset.ntest_class * nSample, S_dim)
    gen_label = np.zeros([0])
    with torch.no_grad():
        for i in range(dataset.ntest_class):
            text_feat = np.tile(dataset.test_att[i].astype('float32'), (nSample, 1))
            text_feat = torch.from_numpy(text_feat)#.to(opt.gpu)
            z = torch.randn(nSample, Z_dim)#.to(opt.gpu)
            G_sample = ae.encoder(netG.decode(z, text_feat))[:,:S_dim]
            gen_feat[i*nSample:(i+1)*nSample] = G_sample
            gen_label = np.hstack((gen_label, np.ones([nSample])*i))
    return gen_feat, torch.from_numpy(gen_label.astype(int))

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if 'Linear' in classname:
        init.xavier_normal_(m.weight.data)
        init.constant_(m.bias, 0.0)

# %%
def log_print(s, log):
    print(s)
    with open(log, 'a') as f:
        f.write(s + '\n')

# %%
def synthesize_feature_test_ori(netG, dataset, opt):
    gen_feat = torch.FloatTensor(dataset.ntest_class * opt.nSample, opt.X_dim)
    gen_label = np.zeros([0])
    with torch.no_grad():
        for i in range(dataset.ntest_class):
            text_feat = np.tile(dataset.test_att[i].astype('float32'), (opt.nSample, 1))
            text_feat = torch.from_numpy(text_feat).to(opt.gpu)
            z = torch.randn(opt.nSample, opt.Z_dim).to(opt.gpu)
            G_sample = netG.decode(z, text_feat)
            gen_feat[i*opt.nSample:(i+1)*opt.nSample] = G_sample
            gen_label = np.hstack((gen_label, np.ones([opt.nSample])*i))
    return gen_feat, torch.from_numpy(gen_label.astype(int))


def save_model(it, model, random_seed, log, fout):
    torch.save({
        'it': it + 1,
        'state_dict': model.state_dict(),
        'random_seed': random_seed,
        'log': log,
    }, fout)


def compute_per_class_acc_gzsl(test_label, predicted_label, target_classes):
    acc_per_class = 0
    for i in test_label.unique():
        idx = (test_label == i)
        acc_per_class += float(torch.sum(test_label[idx] == predicted_label[idx])) / float(torch.sum(idx))
    acc_per_class /= float(target_classes.size(0))
    return acc_per_class


def eval_MCA(preds, y):
    cls_label = np.unique(y)
    acc = list()
    for i in cls_label:
        acc.append((preds[y == i] == i).mean())
    return np.asarray(acc).mean()

# %%
class CLASSIFIER:
    # train_Y is interger
    def __init__(self, _train_X, _train_Y, data_loader, test_seen_feature, test_unseen_feature, _nclass, _cuda, _lr = 0.001, 
                 _beta1 = 0.5, _nepoch = 20, _batch_size = 100,  generalized = True, MCA = True):
        self.train_X =  _train_X
        self.train_Y = _train_Y
        self.test_seen_feature = test_seen_feature
        self.test_seen_label = data_loader.test_seen_label

        self.test_unseen_feature = test_unseen_feature
        self.test_unseen_label = data_loader.test_unseen_label

        self.seenclasses = data_loader.seenclasses
        self.unseenclasses = data_loader.unseenclasses
        self.ntrain_class = data_loader.ntrain_class
        self.batch_size = _batch_size
        self.nepoch = _nepoch
        self.nclass = _nclass
        self.input_dim = _train_X.shape[1]
        #self.cuda = _cuda
        self.MCA = MCA
        self.model =  LINEAR_LOGSOFTMAX(self.input_dim, self.nclass)
        self.model.apply(weights_init)
        self.criterion = nn.NLLLoss()
        #self.opt = opt
        self.input = torch.FloatTensor(_batch_size, self.input_dim)
        self.label = torch.LongTensor(_batch_size)

        self.lr = _lr
        self.beta1 = _beta1
        self.optimizer = optim.Adam(self.model.parameters(), lr=_lr, betas=(_beta1, 0.999))

        #if self.cuda:
        #    self.model.to(opt.gpu)
        #    self.criterion.to(opt.gpu)
        #    self.input = self.input.to(opt.gpu)
        #    self.label = self.label.to(opt.gpu)

        self.index_in_epoch = 0
        self.epochs_completed = 0
        self.ntrain = self.train_X.shape[0]

        if generalized:
            self.acc_seen, self.acc_unseen, self.H = self.fit()
        else:
            self.acc = self.fit_zsl()

    def fit_zsl(self):
        best_acc = 0
        mean_loss = 0
        last_loss_epoch = 1e8
        for epoch in range(self.nepoch):
            for i in range(0, self.ntrain, self.batch_size):
                self.model.zero_grad()
                batch_input, batch_label = self.next_batch(self.batch_size)
                self.input.copy_(batch_input)
                self.label.copy_(batch_label)

                inputv = Variable(self.input)
                labelv = Variable(self.label)
                output = self.model(inputv)
                loss = self.criterion(output, labelv)
                mean_loss += loss.item()
                loss.backward()
                self.optimizer.step()
            acc = self.val(self.test_unseen_feature, self.test_unseen_label, self.unseenclasses)
            if acc > best_acc:
                best_acc = acc
        return best_acc * 100

    def fit(self):
        best_H = 0
        best_seen = 0
        best_unseen = 0
        for epoch in range(self.nepoch):
            for i in range(0, self.ntrain, self.batch_size):
                self.model.zero_grad()
                batch_input, batch_label = self.next_batch(self.batch_size)
                self.input.copy_(batch_input)
                self.label.copy_(batch_label)

                inputv = Variable(self.input)
                labelv = Variable(self.label)
                output = self.model(inputv)
                loss = self.criterion(output, labelv)
                loss.backward()
                self.optimizer.step()

            acc_seen = self.val_gzsl(self.test_seen_feature, self.test_seen_label)
            acc_unseen = self.val_gzsl(self.test_unseen_feature, self.test_unseen_label+self.ntrain_class)
            H = 2*acc_seen*acc_unseen / (acc_seen+acc_unseen)
            print('acc_seen=%.4f, acc_unseen=%.4f, h=%.4f' % (acc_seen, acc_unseen, H))
            if H > best_H:
                best_seen = acc_seen
                best_unseen = acc_unseen
                best_H = H
        return best_seen * 100, best_unseen * 100, best_H *100

    def next_batch(self, batch_size):
        start = self.index_in_epoch
        # shuffle the data at the first epoch
        if self.epochs_completed == 0 and start == 0:
            perm = torch.randperm(self.ntrain)
            self.train_X = self.train_X[perm]
            self.train_Y = self.train_Y[perm]
        # the last batch
        if start + batch_size > self.ntrain:
            self.epochs_completed += 1
            rest_num_examples = self.ntrain - start
            if rest_num_examples > 0:
                X_rest_part = self.train_X[start:self.ntrain]
                Y_rest_part = self.train_Y[start:self.ntrain]
            # shuffle the data
            perm = torch.randperm(self.ntrain)
            self.train_X = self.train_X[perm]
            self.train_Y = self.train_Y[perm]
            # start next epoch
            start = 0
            self.index_in_epoch = batch_size - rest_num_examples
            end = self.index_in_epoch
            X_new_part = self.train_X[start:end]
            Y_new_part = self.train_Y[start:end]
            #print(start, end)
            if rest_num_examples > 0:
                return torch.cat((X_rest_part, X_new_part), 0) , torch.cat((Y_rest_part, Y_new_part), 0)
            else:
                return X_new_part, Y_new_part
        else:
            self.index_in_epoch += batch_size
            end = self.index_in_epoch
            # from index start to index end-1
            return self.train_X[start:end], self.train_Y[start:end]


    def val_gzsl(self, test_X, test_label):
        start = 0
        ntest = test_X.size()[0]
        predicted_label = torch.LongTensor(test_label.size())
        with torch.no_grad():
            for i in range(0, ntest, self.batch_size):
                end = min(ntest, start+self.batch_size)
                #if self.cuda:
                #    output = self.model(test_X[start:end])#.to(self.opt.gpu))
                #else:
                output = self.model(test_X[start:end])
                _, predicted_label[start:end] = torch.max(output.data, 1)
                start = end
        if self.MCA:
            acc = self.eval_MCA(predicted_label.numpy(), test_label.numpy())
        else:
            acc = (predicted_label.numpy() == test_label.numpy()).mean()
        return acc

    def eval_MCA(self, preds, y):
        cls_label = np.unique(y)
        acc = list()
        for i in cls_label:
            acc.append((preds[y == i] == i).mean())
        return np.asarray(acc).mean()

    def compute_per_class_acc_gzsl(self, test_label, predicted_label, target_classes):
        acc_per_class = 0
        for i in target_classes:
            idx = (test_label == i)
            acc_per_class += torch.sum(test_label[idx]==predicted_label[idx]).float() / torch.sum(idx)
        acc_per_class /= target_classes.size(0)
        return acc_per_class

    # test_label is integer
    def val(self, test_X, test_label, target_classes):
        start = 0
        ntest = test_X.size()[0]
        predicted_label = torch.LongTensor(test_label.size())
        with torch.no_grad():
            for i in range(0, ntest, self.batch_size):
                end = min(ntest, start+self.batch_size)
                #if self.cuda:
                #    output = self.model(test_X[start:end])#.to(self.opt.gpu))
                #else:
                output = self.model(test_X[start:end])
                _, predicted_label[start:end] = torch.max(output.data, 1)
                start = end
        if self.MCA:
            acc = self.eval_MCA(predicted_label.numpy(), test_label.numpy())
        else:
            acc = (predicted_label.numpy() == test_label.numpy()).mean()
        print(acc)
        return acc

    def compute_per_class_acc(self, test_label, predicted_label, nclass):
        acc_per_class = torch.FloatTensor(nclass).fill_(0)
        for i in range(nclass):
            idx = (test_label == i)
            acc_per_class[i] = torch.sum(test_label[idx]==predicted_label[idx]).float() / torch.sum(idx)
        return acc_per_class.mean()

# %%
class LINEAR_LOGSOFTMAX(nn.Module):
    def __init__(self, input_dim, nclass):
        super(LINEAR_LOGSOFTMAX, self).__init__()
        self.fc = nn.Linear(input_dim, nclass)
        self.logic = nn.LogSoftmax(dim=1)
    def forward(self, x):
        o = self.logic(self.fc(x))
        return o

# %%
 
dataset_name = 'CUB' 
ga  = 1 
beta = 0.003 
dis = 0.3 
nSample = 1200 
#gpu = 1 
S_dim = 2048 
NS_dim = 2048 
lr = 0.00003
classifier_lr = 0.002 
gen_nepoch = 600
kl_warmup = 0.001 
tc_warmup = 0.0001 
weight_decay = 1e-8
vae_dec_drop = 0.1 
dis_step = 3
ae_drop = 0.0 
finetune = True

# %%
def train(dataset_name, dataroot, workers, image_embedding, class_embedding, gen_nepoch, lr, zsl, finetune, ga, beta, 
          weight_decay, dis, dis_step, kl_warmup, tc_warmup, vae_dec_drop, vae_enc_drop, ae_drop, classifier_lr, 
          classifier_steps, batchsize, nSample, disp_interval, save_interval, evl_interval, evl_start, manualSeed, latent_dim, 
          q_z_nn_output_dim, S_dim, NS_dim):
       
    dataset = DATA_LOADER(finetune, dataset_name, dataroot, class_embedding, image_embedding)
    C_dim = dataset.att_dim
    X_dim = dataset.feature_dim
    Z_dim = latent_dim
    y_dim = dataset.ntrain_class
    
    out_dir = 'out/{}/finetune-{}/wd-{}_b-{}_g-{}_lr-{}_sd-{}_dis-{}_nS-{}_nZ-{}_bs-{}'.format(dataset_name, finetune, weight_decay, beta, ga, 
                                                                                   lr, S_dim, dis, nSample, Z_dim, batchsize)
    print(out_dir)
    
    os.makedirs(out_dir, exist_ok=True)
    print("The output dictionary is {}".format(out_dir))

    log_dir = out_dir + '/log_{}.txt'.format(dataset_name)
    with open(log_dir, 'w') as f:
        f.write('Training Start:')
        f.write(strftime("%a, %d %b %Y %H:%M:%S +0000", gmtime()) + '\n')

    dataset.feature_dim = dataset.train_feature.shape[1]
    X_dim = dataset.feature_dim
    Z_dim = latent_dim
    y_dim = dataset.ntrain_class

    data_layer = FeatDataLayer(dataset.train_label.numpy(), dataset.train_feature.cpu().numpy(), batchsize)

    niter = int(dataset.ntrain/batchsize) * gen_nepoch

    result_gzsl_soft = Result()
    result_zsl_soft = Result()

    model = VAE(Z_dim, S_dim, q_z_nn_output_dim, X_dim, C_dim, vae_enc_drop, vae_dec_drop)#.to(opt.gpu)
    relationNet = RelationNet(C_dim, S_dim)#.to(opt.gpu)
    discriminator = Discriminator(S_dim)#.to(opt.gpu)
    ae = AE(X_dim, S_dim, NS_dim, ae_drop)#.to(opt.gpu)
    print(model)

    with open(log_dir, 'a') as f:
        f.write('\n')
        f.write('Generative Model Training Start:')
        f.write(strftime("%a, %d %b %Y %H:%M:%S +0000", gmtime()) + '\n')

    start_step = 0
    optimizer = optim.Adam(model.parameters(), lr = lr, weight_decay = weight_decay)
    relation_optimizer = optim.Adam(relationNet.parameters(), lr = lr, weight_decay = weight_decay)
    dis_optimizer = optim.Adam(discriminator.parameters(), lr = lr, weight_decay = weight_decay)
    ae_optimizer = optim.Adam(ae.parameters(), lr = lr, weight_decay = weight_decay)
    ones = torch.ones(batchsize, dtype = torch.long)#, device=opt.gpu)
    zeros = torch.zeros(batchsize, dtype = torch.long)#, device=opt.gpu)
    mse = nn.MSELoss()#.to(opt.gpu)


    iters = math.ceil(dataset.ntrain/batchsize)
    beta = 0.01
    coin = 0
    gamma = 0
    for it in range(start_step, niter+1):

        if it % iters == 0:
            beta = min(kl_warmup*(it/iters), 1)
            gamma = min(tc_warmup * (it / iters), 1)

        blobs = data_layer.forward()
        feat_data = blobs['data']
        labels_numpy = blobs['labels'].astype(int)
        labels = torch.from_numpy(labels_numpy.astype('int'))#.to(opt.gpu)

        C = np.array([dataset.train_att[i,:] for i in labels])
        C = torch.from_numpy(C.astype('float32'))#.to(opt.gpu)
        X = torch.from_numpy(feat_data)#.to(opt.gpu)
        
        sample_C = torch.from_numpy(np.array([dataset.train_att[i, :] for i in labels.unique()]))#.to(opt.gpu)
        sample_C_n = labels.unique().shape[0]
        sample_label = labels.unique().cpu()

        x_mean, z_mu, z_var, z = model(X, C)
        loss, ce, kl = multinomial_loss_function(x_mean, X, z_mu, z_var, z, beta = beta)

        sample_labels = np.array(sample_label)
        re_batch_labels = []
        for label in labels_numpy:
            index = np.argwhere(sample_labels == label)
            re_batch_labels.append(index[0][0])
        re_batch_labels = torch.LongTensor(re_batch_labels)
        one_hot_labels = torch.zeros(batchsize, sample_C_n).scatter_(1, re_batch_labels.view(-1, 1), 1)#.to(opt.gpu)

        # one_hot_labels = torch.tensor(
        #     torch.zeros(opt.batchsize, sample_C_n).scatter_(1, re_batch_labels.view(-1, 1), 1)).to(opt.gpu)

        x1, h1, hs1, hn1 = ae(x_mean)
        relations = relationNet(hs1, sample_C)
        relations = relations.view(-1, labels.unique().cpu().shape[0])

        p_loss = ga * mse(relations, one_hot_labels)

        x2, h2, hs2, hn2 = ae(X)
        relations = relationNet(hs2, sample_C)
        relations = relations.view(-1, labels.unique().cpu().shape[0])

        p_loss = p_loss + ga * mse(relations, one_hot_labels)

        rec = mse(x1, X) + mse(x2, X)
        if coin > 0:
            s_score = discriminator(h1)
            tc_loss = beta * gamma *((s_score[:, :1] - s_score[:, 1:]).mean())
            s_score = discriminator(h2)
            tc_loss = tc_loss + beta * gamma* ((s_score[:, :1] - s_score[:, 1:]).mean())

            loss = loss + p_loss + rec + tc_loss
            coin -= 1
        else:
            s, n = permute_dims(hs1, hn1)
            b = torch.cat((s, n), 1).detach()
            s_score = discriminator(h1)
            n_score = discriminator(b)
            tc_loss = dis * (F.cross_entropy(s_score, zeros) + F.cross_entropy(n_score, ones))

            s, n = permute_dims(hs2, hn2)
            b = torch.cat((s, n), 1).detach()
            s_score = discriminator(h2)
            n_score = discriminator(b)
            tc_loss = tc_loss + dis * (F.cross_entropy(s_score, zeros) + F.cross_entropy(n_score, ones))

            dis_optimizer.zero_grad()
            tc_loss.backward(retain_graph=True)
            dis_optimizer.step()

            loss = loss + p_loss + rec
            coin += dis_step
        optimizer.zero_grad()
        relation_optimizer.zero_grad()
        ae_optimizer.zero_grad()

        loss.backward()

        optimizer.step()
        relation_optimizer.step()
        ae_optimizer.step()

        if it % disp_interval == 0 and it:
            log_text = 'Iter-[{}/{}]; loss: {:.3f}; kl:{:.3f}; p_loss:{:.3f}; rec:{:.3f}; tc:{:.3f}; gamma:{:.3f};'.format(it,
                                             niter, loss.item(), kl.item(), p_loss.item(), rec.item(), tc_loss.item(), gamma)
            log_print(log_text, log_dir)

        if it % evl_interval == 0 and it > evl_start:
            model.eval()
            ae.eval()
            gen_feat, gen_label = synthesize_feature_test(model, ae, dataset, nSample, S_dim, Z_dim)
            with torch.no_grad():
                train_feature = ae.encoder(dataset.train_feature)[:,:S_dim].cpu()
                test_unseen_feature = ae.encoder(dataset.test_unseen_feature)[:,:S_dim].cpu()
                test_seen_feature = ae.encoder(dataset.test_seen_feature)[:,:S_dim].cpu()

            train_X = torch.cat((train_feature, gen_feat), 0)
            train_Y = torch.cat((dataset.train_label, gen_label + dataset.ntrain_class), 0)
            if zsl:
                """ZSL"""
                cls = CLASSIFIER(gen_feat, gen_label, dataset, test_seen_feature, test_unseen_feature,
                                            dataset.ntrain_class + dataset.ntest_class, True, classifier_lr, 0.5, 20,
                                            nSample, False)
                result_zsl_soft.update(it, cls.acc)
                log_print("ZSL Softmax:", log_dir)
                log_print("Acc {:.2f}%  Best_acc [{:.2f}% | Iter-{}]".format(
                    cls.acc, result_zsl_soft.best_acc, result_zsl_soft.best_iter), log_dir)

            else:
                """ GZSL"""
                cls = CLASSIFIER(train_X, train_Y, dataset, test_seen_feature, test_unseen_feature,
                                            dataset.ntrain_class + dataset.ntest_class, True, classifier_lr, 0.5,
                                            classifier_steps, nSample, True)

                result_gzsl_soft.update_gzsl(it, cls.acc_seen, cls.acc_unseen, cls.H)

                log_print("GZSL Softmax:", log_dir)
                log_print("U->T {:.2f}%  S->T {:.2f}%  H {:.2f}%  Best_H [{:.2f}% {:.2f}% {:.2f}% | Iter-{}]".format(
                    cls.acc_unseen, cls.acc_seen, cls.H,  result_gzsl_soft.best_acc_U_T, result_gzsl_soft.best_acc_S_T,
                    result_gzsl_soft.best_acc, result_gzsl_soft.best_iter), log_dir)

                if result_gzsl_soft.save_model:
                    files2remove = glob.glob(out_dir + '/Best_model_GZSL_*')
                    for _i in files2remove:
                        os.remove(_i)
                    save_model(it, model, manualSeed, log_text,
                               out_dir + '/Best_model_GZSL_H_{:.2f}_S_{:.2f}_U_{:.2f}.tar'.format(result_gzsl_soft.best_acc,
                                                                                                 result_gzsl_soft.best_acc_S_T,
                                                                                                 result_gzsl_soft.best_acc_U_T))
            ###############################################################################################################

            # retrieval code
            cls_centrild = np.zeros((dataset.ntest_class, S_dim))
            for i in range(dataset.ntest_class):
                cls_centrild[i] = torch.mean(gen_feat[gen_label == i,], dim=0)
            dist = cosine_similarity(cls_centrild, test_unseen_feature)

            precision_100 = torch.zeros(dataset.ntest_class)
            precision_50 = torch.zeros(dataset.ntest_class)
            precision_25 = torch.zeros(dataset.ntest_class)

            dist = torch.from_numpy(-dist)
            for i in range(dataset.ntest_class):
                is_class = dataset.test_unseen_label == i
                # print(is_class.sum())
                cls_num = int(is_class.sum())

                # 100%
                _, idx = torch.topk(dist[i, :], cls_num, largest=False)
                precision_100[i] = (is_class[idx]).sum().float() / cls_num

                # 50%
                cls_num_50 = int(cls_num / 2)
                _, idx = torch.topk(dist[i, :], cls_num_50, largest=False)
                precision_50[i] = (is_class[idx]).sum().float() / cls_num_50

                # 25%
                cls_num_25 = int(cls_num / 4)
                _, idx = torch.topk(dist[i, :], cls_num_25, largest=False)
                precision_25[i] = (is_class[idx]).sum().float() / cls_num_25
            print("retrieval results 100%%: %.3f 50%%: %.3f 25%%: %.3f" % (precision_100.mean().item(),
                                                                           precision_50.mean().item(),
                                                                           precision_25.mean().item()))
            ###############################################################################################################
            model.train()
            ae.train()
        if it % save_interval == 0 and it:
            save_model(it, model, manualSeed, log_text,
                       out_dir + '/Iter_{:d}.tar'.format(it))
            print('Save model to ' + out_dir + '/Iter_{:d}.tar'.format(it))

# %%
train(dataset_name, dataroot, workers, image_embedding, class_embedding, gen_nepoch, lr, zsl, finetune, ga, beta, 
          weight_decay, dis, dis_step, kl_warmup, tc_warmup, vae_dec_drop, vae_enc_drop, ae_drop, classifier_lr, 
          classifier_steps, batchsize, nSample, disp_interval, save_interval, evl_interval, evl_start, manualSeed, 
          latent_dim, q_z_nn_output_dim, S_dim, NS_dim)
# Out:
# out/CUB/finetune-True/wd-1e-08_b-0.003_g-1_lr-3e-05_sd-2048_dis-0.3_nS-1200_nZ-20_bs-64
# The output dictionary is out/CUB/finetune-True/wd-1e-08_b-0.003_g-1_lr-3e-05_sd-2048_dis-0.3_nS-1200_nZ-20_bs-64
# VAE(
#   (q_z_nn): Sequential(
#     (0): Linear(in_features=2360, out_features=2048, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=2048, out_features=2048, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=2048, out_features=128, bias=True)
#   )
#   (q_z_mean): Linear(in_features=128, out_features=20, bias=True)
#   (q_z_var): Sequential(
#     (0): Linear(in_features=128, out_features=20, bias=True)
#     (1): Dropout(p=0.2, inplace=False)
#     (2): Softplus(beta=1, threshold=20)
#   )
#   (p_x_nn): Sequential(
#     (0): Linear(in_features=332, out_features=2048, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Linear(in_features=2048, out_features=2048, bias=True)
#     (4): BatchNorm1d(2048, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=2048, out_features=2048, bias=True)
#     (7): BatchNorm1d(2048, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (8): Dropout(p=0.1, inplace=False)
#     (9): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (p_x_mean): Sequential(
#     (0): Linear(in_features=2048, out_features=2048, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
# )
# Iter-[200/66000]; loss: 43.081; kl:7.507; p_loss:0.038; rec:0.032; tc:0.832; gamma:0.000;
# Iter-[400/66000]; loss: 37.098; kl:8.246; p_loss:0.038; rec:0.024; tc:0.832; gamma:0.000;
# acc_seen=0.0000, acc_unseen=0.0674, h=0.0000
# acc_seen=0.1607, acc_unseen=0.0925, h=0.1174
# acc_seen=0.5813, acc_unseen=0.1163, h=0.1938
# acc_seen=0.7064, acc_unseen=0.1369, h=0.2293
# acc_seen=0.7576, acc_unseen=0.1181, h=0.2044
# acc_seen=0.7636, acc_unseen=0.1184, h=0.2050
# acc_seen=0.7817, acc_unseen=0.1171, h=0.2036
# acc_seen=0.7888, acc_unseen=0.1509, h=0.2534
# acc_seen=0.7912, acc_unseen=0.1322, h=0.2265
# acc_seen=0.7859, acc_unseen=0.1381, h=0.2349
# acc_seen=0.7795, acc_unseen=0.1486, h=0.2497
# acc_seen=0.7948, acc_unseen=0.1547, h=0.2590
# acc_seen=0.7932, acc_unseen=0.1695, h=0.2794
# acc_seen=0.7885, acc_unseen=0.1889, h=0.3048
# acc_seen=0.7992, acc_unseen=0.1818, h=0.2962
# acc_seen=0.7912, acc_unseen=0.1760, h=0.2879
# acc_seen=0.7889, acc_unseen=0.1934, h=0.3106
# acc_seen=0.7910, acc_unseen=0.1992, h=0.3182
# acc_seen=0.7790, acc_unseen=0.1892, h=0.3045
# acc_seen=0.7931, acc_unseen=0.2039, h=0.3244
# acc_seen=0.7929, acc_unseen=0.1942, h=0.3120
# acc_seen=0.7807, acc_unseen=0.1927, h=0.3091
# acc_seen=0.7948, acc_unseen=0.2012, h=0.3211
# acc_seen=0.7904, acc_unseen=0.2036, h=0.3238
# acc_seen=0.7929, acc_unseen=0.1917, h=0.3087
# acc_seen=0.7875, acc_unseen=0.1997, h=0.3186
# acc_seen=0.7930, acc_unseen=0.2269, h=0.3529
# acc_seen=0.7878, acc_unseen=0.2083, h=0.3295
# acc_seen=0.7893, acc_unseen=0.2017, h=0.3212
# acc_seen=0.7962, acc_unseen=0.2151, h=0.3387
# acc_seen=0.7970, acc_unseen=0.2162, h=0.3401
# acc_seen=0.8008, acc_unseen=0.2184, h=0.3432
# acc_seen=0.7939, acc_unseen=0.2379, h=0.3660
# acc_seen=0.7909, acc_unseen=0.2280, h=0.3540
# acc_seen=0.7906, acc_unseen=0.2094, h=0.3311
# acc_seen=0.7922, acc_unseen=0.2359, h=0.3635
# acc_seen=0.7896, acc_unseen=0.2152, h=0.3382
# acc_seen=0.7917, acc_unseen=0.2250, h=0.3504
# acc_seen=0.7869, acc_unseen=0.2142, h=0.3368
# acc_seen=0.7915, acc_unseen=0.2285, h=0.3547
# acc_seen=0.7949, acc_unseen=0.2243, h=0.3499
# acc_seen=0.7926, acc_unseen=0.2168, h=0.3404
# acc_seen=0.7927, acc_unseen=0.2153, h=0.3386
# acc_seen=0.7936, acc_unseen=0.2254, h=0.3511
# acc_seen=0.7924, acc_unseen=0.2220, h=0.3469
# acc_seen=0.7869, acc_unseen=0.2274, h=0.3529
# acc_seen=0.7900, acc_unseen=0.2344, h=0.3615
# acc_seen=0.7857, acc_unseen=0.2171, h=0.3402
# acc_seen=0.7897, acc_unseen=0.2277, h=0.3535
# acc_seen=0.7899, acc_unseen=0.2337, h=0.3607
# GZSL Softmax:
# U->T 23.79%  S->T 79.39%  H 36.60%  Best_H [79.39% 23.79% 36.60% | Iter-400]
# retrieval results 100%: 0.043 50%: 0.045 25%: 0.049
# Iter-[600/66000]; loss: 28.914; kl:29.399; p_loss:0.036; rec:0.018; tc:0.832; gamma:0.001;
# Iter-[800/66000]; loss: 25.145; kl:36.056; p_loss:0.038; rec:0.016; tc:0.832; gamma:0.001;
# acc_seen=0.0000, acc_unseen=0.2488, h=0.0000
# acc_seen=0.2192, acc_unseen=0.3493, h=0.2693
# acc_seen=0.4987, acc_unseen=0.3244, h=0.3931
# acc_seen=0.6026, acc_unseen=0.3520, h=0.4444
# acc_seen=0.6716, acc_unseen=0.3825, h=0.4874
# acc_seen=0.6885, acc_unseen=0.3538, h=0.4674
# acc_seen=0.7121, acc_unseen=0.3562, h=0.4749
# acc_seen=0.7259, acc_unseen=0.3584, h=0.4799
# acc_seen=0.7221, acc_unseen=0.3465, h=0.4683
# acc_seen=0.7419, acc_unseen=0.3475, h=0.4733
# acc_seen=0.7215, acc_unseen=0.3589, h=0.4793
# acc_seen=0.7448, acc_unseen=0.3450, h=0.4715
# acc_seen=0.7465, acc_unseen=0.3406, h=0.4678
# acc_seen=0.7439, acc_unseen=0.3429, h=0.4694
# acc_seen=0.7473, acc_unseen=0.3308, h=0.4586
# acc_seen=0.7468, acc_unseen=0.3416, h=0.4687
# acc_seen=0.7436, acc_unseen=0.3377, h=0.4645
# acc_seen=0.7435, acc_unseen=0.3471, h=0.4733
# acc_seen=0.7426, acc_unseen=0.3329, h=0.4597
# acc_seen=0.7503, acc_unseen=0.3247, h=0.4532
# acc_seen=0.7539, acc_unseen=0.3198, h=0.4491
# acc_seen=0.7501, acc_unseen=0.3190, h=0.4476
# acc_seen=0.7524, acc_unseen=0.3265, h=0.4554
# acc_seen=0.7540, acc_unseen=0.3207, h=0.4500
# acc_seen=0.7466, acc_unseen=0.3074, h=0.4355
# acc_seen=0.7461, acc_unseen=0.3080, h=0.4360
# acc_seen=0.7484, acc_unseen=0.3174, h=0.4458
# acc_seen=0.7520, acc_unseen=0.3086, h=0.4376
# acc_seen=0.7544, acc_unseen=0.3108, h=0.4402
# acc_seen=0.7521, acc_unseen=0.3031, h=0.4321
# acc_seen=0.7521, acc_unseen=0.3022, h=0.4311
# acc_seen=0.7498, acc_unseen=0.3011, h=0.4297
# acc_seen=0.7481, acc_unseen=0.2951, h=0.4232
# acc_seen=0.7548, acc_unseen=0.2993, h=0.4286
# acc_seen=0.7510, acc_unseen=0.3016, h=0.4303
# acc_seen=0.7515, acc_unseen=0.2942, h=0.4229
# acc_seen=0.7519, acc_unseen=0.2844, h=0.4127
# acc_seen=0.7534, acc_unseen=0.2845, h=0.4130
# acc_seen=0.7539, acc_unseen=0.2939, h=0.4230
# acc_seen=0.7548, acc_unseen=0.2932, h=0.4223
# acc_seen=0.7588, acc_unseen=0.2766, h=0.4054
# acc_seen=0.7554, acc_unseen=0.2764, h=0.4047
# acc_seen=0.7567, acc_unseen=0.2834, h=0.4124
# acc_seen=0.7530, acc_unseen=0.2820, h=0.4103
# acc_seen=0.7560, acc_unseen=0.2806, h=0.4093
# acc_seen=0.7553, acc_unseen=0.2718, h=0.3998
# acc_seen=0.7529, acc_unseen=0.2768, h=0.4048
# acc_seen=0.7543, acc_unseen=0.2762, h=0.4043
# acc_seen=0.7540, acc_unseen=0.2815, h=0.4099
# acc_seen=0.7537, acc_unseen=0.2718, h=0.3995
# GZSL Softmax:
# U->T 38.25%  S->T 67.16%  H 48.74%  Best_H [67.16% 38.25% 48.74% | Iter-800]
# retrieval results 100%: 0.145 50%: 0.167 25%: 0.183
# Iter-[1000/66000]; loss: 22.184; kl:45.736; p_loss:0.038; rec:0.014; tc:0.832; gamma:0.001;
# Iter-[1200/66000]; loss: 18.162; kl:49.127; p_loss:0.040; rec:0.011; tc:0.832; gamma:0.001;
# acc_seen=0.0030, acc_unseen=0.3447, h=0.0060
# acc_seen=0.2392, acc_unseen=0.4447, h=0.3111
# acc_seen=0.5121, acc_unseen=0.4319, h=0.4686
# acc_seen=0.6385, acc_unseen=0.3967, h=0.4894
# acc_seen=0.6696, acc_unseen=0.4054, h=0.5050
# acc_seen=0.6897, acc_unseen=0.3849, h=0.4941
# acc_seen=0.7049, acc_unseen=0.3953, h=0.5065
# acc_seen=0.7192, acc_unseen=0.3759, h=0.4938
# acc_seen=0.7073, acc_unseen=0.3693, h=0.4853
# acc_seen=0.7355, acc_unseen=0.3667, h=0.4894
# acc_seen=0.7269, acc_unseen=0.3521, h=0.4744
# acc_seen=0.7355, acc_unseen=0.3562, h=0.4799
# acc_seen=0.7424, acc_unseen=0.3503, h=0.4760
# acc_seen=0.7318, acc_unseen=0.3449, h=0.4688
# acc_seen=0.7323, acc_unseen=0.3406, h=0.4650
# acc_seen=0.7465, acc_unseen=0.3379, h=0.4653
# acc_seen=0.7482, acc_unseen=0.3230, h=0.4513
# acc_seen=0.7391, acc_unseen=0.3337, h=0.4598
# acc_seen=0.7475, acc_unseen=0.3253, h=0.4534
# acc_seen=0.7546, acc_unseen=0.3280, h=0.4573
# acc_seen=0.7509, acc_unseen=0.3214, h=0.4501
# acc_seen=0.7422, acc_unseen=0.3231, h=0.4502
# acc_seen=0.7627, acc_unseen=0.3122, h=0.4431
# acc_seen=0.7593, acc_unseen=0.3057, h=0.4359
# acc_seen=0.7602, acc_unseen=0.3119, h=0.4423
# acc_seen=0.7547, acc_unseen=0.3124, h=0.4419
# acc_seen=0.7593, acc_unseen=0.3022, h=0.4323
# acc_seen=0.7641, acc_unseen=0.3061, h=0.4371
# acc_seen=0.7616, acc_unseen=0.2915, h=0.4216
# acc_seen=0.7599, acc_unseen=0.3029, h=0.4331
# acc_seen=0.7613, acc_unseen=0.2982, h=0.4286
# acc_seen=0.7671, acc_unseen=0.2950, h=0.4261
# acc_seen=0.7683, acc_unseen=0.2914, h=0.4226
# acc_seen=0.7665, acc_unseen=0.2888, h=0.4195
# acc_seen=0.7669, acc_unseen=0.2899, h=0.4207
# acc_seen=0.7694, acc_unseen=0.2883, h=0.4194
# acc_seen=0.7657, acc_unseen=0.2963, h=0.4273
# acc_seen=0.7645, acc_unseen=0.2944, h=0.4251
# acc_seen=0.7661, acc_unseen=0.2914, h=0.4222
# acc_seen=0.7639, acc_unseen=0.2885, h=0.4189
# acc_seen=0.7659, acc_unseen=0.2905, h=0.4213
# acc_seen=0.7680, acc_unseen=0.2881, h=0.4191
# acc_seen=0.7662, acc_unseen=0.2829, h=0.4132
# acc_seen=0.7697, acc_unseen=0.2834, h=0.4143
# acc_seen=0.7703, acc_unseen=0.2793, h=0.4100
# acc_seen=0.7675, acc_unseen=0.2819, h=0.4124
# acc_seen=0.7704, acc_unseen=0.2849, h=0.4160
# acc_seen=0.7702, acc_unseen=0.2843, h=0.4153
# acc_seen=0.7738, acc_unseen=0.2813, h=0.4127
# acc_seen=0.7689, acc_unseen=0.2757, h=0.4059
# GZSL Softmax:
# U->T 39.53%  S->T 70.49%  H 50.65%  Best_H [70.49% 39.53% 50.65% | Iter-1200]
# retrieval results 100%: 0.206 50%: 0.238 25%: 0.269
# Iter-[1400/66000]; loss: 17.567; kl:51.722; p_loss:0.041; rec:0.011; tc:0.832; gamma:0.001;
# Iter-[1600/66000]; loss: 15.963; kl:49.223; p_loss:0.038; rec:0.009; tc:0.832; gamma:0.001;
# acc_seen=0.0000, acc_unseen=0.4270, h=0.0000
# acc_seen=0.2229, acc_unseen=0.4748, h=0.3034
# acc_seen=0.5204, acc_unseen=0.4486, h=0.4818
# acc_seen=0.6166, acc_unseen=0.4387, h=0.5127
# acc_seen=0.6701, acc_unseen=0.4106, h=0.5092
# acc_seen=0.6970, acc_unseen=0.4174, h=0.5221
# acc_seen=0.7031, acc_unseen=0.3994, h=0.5095
# acc_seen=0.7100, acc_unseen=0.3924, h=0.5055
# acc_seen=0.7188, acc_unseen=0.3860, h=0.5023
# acc_seen=0.7221, acc_unseen=0.3853, h=0.5025
# acc_seen=0.7228, acc_unseen=0.3764, h=0.4950
# acc_seen=0.7262, acc_unseen=0.3612, h=0.4824
# acc_seen=0.7281, acc_unseen=0.3626, h=0.4842
# acc_seen=0.7333, acc_unseen=0.3740, h=0.4954
# acc_seen=0.7372, acc_unseen=0.3533, h=0.4776
# acc_seen=0.7370, acc_unseen=0.3526, h=0.4770
# acc_seen=0.7392, acc_unseen=0.3500, h=0.4751
# acc_seen=0.7389, acc_unseen=0.3483, h=0.4734
# acc_seen=0.7451, acc_unseen=0.3435, h=0.4702
# acc_seen=0.7386, acc_unseen=0.3311, h=0.4573
# acc_seen=0.7507, acc_unseen=0.3343, h=0.4626
# acc_seen=0.7454, acc_unseen=0.3397, h=0.4667
# acc_seen=0.7399, acc_unseen=0.3341, h=0.4603
# acc_seen=0.7509, acc_unseen=0.3285, h=0.4571
# acc_seen=0.7470, acc_unseen=0.3232, h=0.4512
# acc_seen=0.7529, acc_unseen=0.3124, h=0.4415
# acc_seen=0.7535, acc_unseen=0.3205, h=0.4497
# acc_seen=0.7557, acc_unseen=0.3148, h=0.4445
# acc_seen=0.7534, acc_unseen=0.3132, h=0.4424
# acc_seen=0.7514, acc_unseen=0.3137, h=0.4426
# acc_seen=0.7501, acc_unseen=0.3164, h=0.4451
# acc_seen=0.7533, acc_unseen=0.3091, h=0.4383
# acc_seen=0.7582, acc_unseen=0.3072, h=0.4373
# acc_seen=0.7556, acc_unseen=0.3110, h=0.4406
# acc_seen=0.7523, acc_unseen=0.3064, h=0.4354
# acc_seen=0.7538, acc_unseen=0.3128, h=0.4421
# acc_seen=0.7552, acc_unseen=0.3019, h=0.4314
# acc_seen=0.7562, acc_unseen=0.2979, h=0.4274
# acc_seen=0.7589, acc_unseen=0.3021, h=0.4322
# acc_seen=0.7607, acc_unseen=0.2973, h=0.4275
# acc_seen=0.7607, acc_unseen=0.2974, h=0.4276
# acc_seen=0.7579, acc_unseen=0.2950, h=0.4247
# acc_seen=0.7572, acc_unseen=0.2967, h=0.4264
# acc_seen=0.7605, acc_unseen=0.2961, h=0.4262
# acc_seen=0.7588, acc_unseen=0.2922, h=0.4219
# acc_seen=0.7627, acc_unseen=0.2901, h=0.4203
# acc_seen=0.7594, acc_unseen=0.2966, h=0.4266
# acc_seen=0.7588, acc_unseen=0.2903, h=0.4200
# acc_seen=0.7631, acc_unseen=0.2916, h=0.4220
# acc_seen=0.7581, acc_unseen=0.2846, h=0.4138
# GZSL Softmax:
# U->T 41.74%  S->T 69.70%  H 52.21%  Best_H [69.70% 41.74% 52.21% | Iter-1600]
# retrieval results 100%: 0.226 50%: 0.262 25%: 0.290
# Iter-[1800/66000]; loss: 14.542; kl:51.187; p_loss:0.038; rec:0.009; tc:0.832; gamma:0.002;
# Iter-[2000/66000]; loss: 13.565; kl:47.730; p_loss:0.035; rec:0.008; tc:0.831; gamma:0.002;
# acc_seen=0.0051, acc_unseen=0.4331, h=0.0101
# acc_seen=0.2506, acc_unseen=0.4893, h=0.3314
# acc_seen=0.5322, acc_unseen=0.4681, h=0.4981
# acc_seen=0.6140, acc_unseen=0.4594, h=0.5255
# acc_seen=0.6662, acc_unseen=0.4492, h=0.5366
# acc_seen=0.6823, acc_unseen=0.4336, h=0.5302
# acc_seen=0.6943, acc_unseen=0.4358, h=0.5355
# acc_seen=0.7036, acc_unseen=0.4234, h=0.5287
# acc_seen=0.7062, acc_unseen=0.4031, h=0.5132
# acc_seen=0.7128, acc_unseen=0.3917, h=0.5055
# acc_seen=0.7119, acc_unseen=0.3940, h=0.5072
# acc_seen=0.7217, acc_unseen=0.3891, h=0.5056
# acc_seen=0.7271, acc_unseen=0.3887, h=0.5066
# acc_seen=0.7280, acc_unseen=0.3704, h=0.4910
# acc_seen=0.7285, acc_unseen=0.3747, h=0.4948
# acc_seen=0.7351, acc_unseen=0.3699, h=0.4921
# acc_seen=0.7332, acc_unseen=0.3633, h=0.4859
# acc_seen=0.7393, acc_unseen=0.3545, h=0.4792
# acc_seen=0.7407, acc_unseen=0.3465, h=0.4721
# acc_seen=0.7478, acc_unseen=0.3495, h=0.4764
# acc_seen=0.7351, acc_unseen=0.3455, h=0.4700
# acc_seen=0.7444, acc_unseen=0.3454, h=0.4718
# acc_seen=0.7409, acc_unseen=0.3445, h=0.4703
# acc_seen=0.7472, acc_unseen=0.3472, h=0.4741
# acc_seen=0.7466, acc_unseen=0.3386, h=0.4659
# acc_seen=0.7429, acc_unseen=0.3388, h=0.4654
# acc_seen=0.7524, acc_unseen=0.3413, h=0.4696
# acc_seen=0.7526, acc_unseen=0.3372, h=0.4657
# acc_seen=0.7469, acc_unseen=0.3388, h=0.4662
# acc_seen=0.7421, acc_unseen=0.3338, h=0.4605
# acc_seen=0.7544, acc_unseen=0.3292, h=0.4584
# acc_seen=0.7497, acc_unseen=0.3287, h=0.4570
# acc_seen=0.7502, acc_unseen=0.3338, h=0.4620
# acc_seen=0.7587, acc_unseen=0.3317, h=0.4616
# acc_seen=0.7551, acc_unseen=0.3230, h=0.4524
# acc_seen=0.7509, acc_unseen=0.3252, h=0.4538
# acc_seen=0.7490, acc_unseen=0.3271, h=0.4554
# acc_seen=0.7555, acc_unseen=0.3285, h=0.4579
# acc_seen=0.7556, acc_unseen=0.3203, h=0.4499
# acc_seen=0.7518, acc_unseen=0.3230, h=0.4518
# acc_seen=0.7548, acc_unseen=0.3266, h=0.4559
# acc_seen=0.7547, acc_unseen=0.3214, h=0.4508
# acc_seen=0.7521, acc_unseen=0.3172, h=0.4462
# acc_seen=0.7557, acc_unseen=0.3171, h=0.4468
# acc_seen=0.7543, acc_unseen=0.3175, h=0.4469
# acc_seen=0.7528, acc_unseen=0.3218, h=0.4509
# acc_seen=0.7582, acc_unseen=0.3147, h=0.4448
# acc_seen=0.7572, acc_unseen=0.3181, h=0.4480
# acc_seen=0.7571, acc_unseen=0.3164, h=0.4463
# acc_seen=0.7592, acc_unseen=0.3103, h=0.4406
# GZSL Softmax:
# U->T 44.92%  S->T 66.62%  H 53.66%  Best_H [66.62% 44.92% 53.66% | Iter-2000]
# retrieval results 100%: 0.242 50%: 0.284 25%: 0.316
# Iter-[2200/66000]; loss: 13.031; kl:46.742; p_loss:0.037; rec:0.008; tc:0.830; gamma:0.002;
# Iter-[2400/66000]; loss: 12.832; kl:48.117; p_loss:0.036; rec:0.007; tc:0.829; gamma:0.002;
# acc_seen=0.0000, acc_unseen=0.4755, h=0.0000
# acc_seen=0.3043, acc_unseen=0.5202, h=0.3839
# acc_seen=0.5314, acc_unseen=0.4965, h=0.5134
# acc_seen=0.6238, acc_unseen=0.4805, h=0.5429
# acc_seen=0.6540, acc_unseen=0.4835, h=0.5559
# acc_seen=0.6796, acc_unseen=0.4678, h=0.5542
# acc_seen=0.6942, acc_unseen=0.4509, h=0.5467
# acc_seen=0.7066, acc_unseen=0.4431, h=0.5446
# acc_seen=0.6997, acc_unseen=0.4319, h=0.5341
# acc_seen=0.7109, acc_unseen=0.4282, h=0.5345
# acc_seen=0.7130, acc_unseen=0.4215, h=0.5298
# acc_seen=0.7195, acc_unseen=0.4109, h=0.5231
# acc_seen=0.7195, acc_unseen=0.4065, h=0.5195
# acc_seen=0.7289, acc_unseen=0.4045, h=0.5203
# acc_seen=0.7269, acc_unseen=0.4009, h=0.5167
# acc_seen=0.7258, acc_unseen=0.3980, h=0.5141
# acc_seen=0.7376, acc_unseen=0.3923, h=0.5122
# acc_seen=0.7356, acc_unseen=0.3878, h=0.5079
# acc_seen=0.7338, acc_unseen=0.3828, h=0.5031
# acc_seen=0.7383, acc_unseen=0.3850, h=0.5061
# acc_seen=0.7466, acc_unseen=0.3764, h=0.5005
# acc_seen=0.7419, acc_unseen=0.3739, h=0.4972
# acc_seen=0.7446, acc_unseen=0.3714, h=0.4956
# acc_seen=0.7497, acc_unseen=0.3708, h=0.4962
# acc_seen=0.7427, acc_unseen=0.3807, h=0.5034
# acc_seen=0.7481, acc_unseen=0.3617, h=0.4876
# acc_seen=0.7426, acc_unseen=0.3709, h=0.4947
# acc_seen=0.7479, acc_unseen=0.3637, h=0.4894
# acc_seen=0.7465, acc_unseen=0.3579, h=0.4838
# acc_seen=0.7506, acc_unseen=0.3659, h=0.4920
# acc_seen=0.7509, acc_unseen=0.3595, h=0.4863
# acc_seen=0.7465, acc_unseen=0.3538, h=0.4801
# acc_seen=0.7533, acc_unseen=0.3512, h=0.4791
# acc_seen=0.7464, acc_unseen=0.3571, h=0.4831
# acc_seen=0.7520, acc_unseen=0.3575, h=0.4846
# acc_seen=0.7535, acc_unseen=0.3480, h=0.4761
# acc_seen=0.7537, acc_unseen=0.3472, h=0.4754
# acc_seen=0.7546, acc_unseen=0.3512, h=0.4793
# acc_seen=0.7569, acc_unseen=0.3491, h=0.4778
# acc_seen=0.7496, acc_unseen=0.3517, h=0.4788
# acc_seen=0.7509, acc_unseen=0.3561, h=0.4831
# acc_seen=0.7550, acc_unseen=0.3466, h=0.4751
# acc_seen=0.7550, acc_unseen=0.3453, h=0.4739
# acc_seen=0.7572, acc_unseen=0.3473, h=0.4762
# acc_seen=0.7588, acc_unseen=0.3495, h=0.4786
# acc_seen=0.7532, acc_unseen=0.3450, h=0.4733
# acc_seen=0.7547, acc_unseen=0.3479, h=0.4762
# acc_seen=0.7578, acc_unseen=0.3456, h=0.4747
# acc_seen=0.7507, acc_unseen=0.3389, h=0.4669
# acc_seen=0.7612, acc_unseen=0.3439, h=0.4738
# GZSL Softmax:
# U->T 48.35%  S->T 65.40%  H 55.59%  Best_H [65.40% 48.35% 55.59% | Iter-2400]
# retrieval results 100%: 0.261 50%: 0.306 25%: 0.332
# Iter-[2600/66000]; loss: 12.255; kl:45.375; p_loss:0.037; rec:0.007; tc:0.827; gamma:0.002;
# Iter-[2800/66000]; loss: 12.566; kl:41.603; p_loss:0.035; rec:0.007; tc:0.823; gamma:0.003;
# acc_seen=0.0025, acc_unseen=0.4950, h=0.0050
# acc_seen=0.3031, acc_unseen=0.5209, h=0.3832
# acc_seen=0.5582, acc_unseen=0.5109, h=0.5335
# acc_seen=0.6299, acc_unseen=0.4939, h=0.5537
# acc_seen=0.6680, acc_unseen=0.4854, h=0.5623
# acc_seen=0.6853, acc_unseen=0.4764, h=0.5620
# acc_seen=0.6799, acc_unseen=0.4648, h=0.5521
# acc_seen=0.7018, acc_unseen=0.4569, h=0.5535
# acc_seen=0.7011, acc_unseen=0.4488, h=0.5472
# acc_seen=0.7104, acc_unseen=0.4396, h=0.5431
# acc_seen=0.7123, acc_unseen=0.4398, h=0.5438
# acc_seen=0.7193, acc_unseen=0.4334, h=0.5408
# acc_seen=0.7219, acc_unseen=0.4229, h=0.5333
# acc_seen=0.7268, acc_unseen=0.4180, h=0.5308
# acc_seen=0.7231, acc_unseen=0.4178, h=0.5296
# acc_seen=0.7297, acc_unseen=0.4095, h=0.5246
# acc_seen=0.7296, acc_unseen=0.3983, h=0.5153
# acc_seen=0.7328, acc_unseen=0.4031, h=0.5201
# acc_seen=0.7366, acc_unseen=0.3967, h=0.5156
# acc_seen=0.7338, acc_unseen=0.4024, h=0.5198
# acc_seen=0.7348, acc_unseen=0.3958, h=0.5145
# acc_seen=0.7346, acc_unseen=0.3942, h=0.5130
# acc_seen=0.7385, acc_unseen=0.3879, h=0.5086
# acc_seen=0.7373, acc_unseen=0.3897, h=0.5099
# acc_seen=0.7429, acc_unseen=0.3854, h=0.5075
# acc_seen=0.7436, acc_unseen=0.3772, h=0.5005
# acc_seen=0.7409, acc_unseen=0.3847, h=0.5064
# acc_seen=0.7464, acc_unseen=0.3847, h=0.5077
# acc_seen=0.7444, acc_unseen=0.3733, h=0.4972
# acc_seen=0.7441, acc_unseen=0.3765, h=0.5000
# acc_seen=0.7478, acc_unseen=0.3796, h=0.5036
# acc_seen=0.7438, acc_unseen=0.3748, h=0.4985
# acc_seen=0.7506, acc_unseen=0.3813, h=0.5057
# acc_seen=0.7518, acc_unseen=0.3693, h=0.4953
# acc_seen=0.7494, acc_unseen=0.3753, h=0.5001
# acc_seen=0.7465, acc_unseen=0.3703, h=0.4951
# acc_seen=0.7467, acc_unseen=0.3711, h=0.4958
# acc_seen=0.7455, acc_unseen=0.3694, h=0.4941
# acc_seen=0.7535, acc_unseen=0.3668, h=0.4934
# acc_seen=0.7480, acc_unseen=0.3687, h=0.4939
# acc_seen=0.7532, acc_unseen=0.3650, h=0.4917
# acc_seen=0.7540, acc_unseen=0.3622, h=0.4894
# acc_seen=0.7576, acc_unseen=0.3658, h=0.4934
# acc_seen=0.7493, acc_unseen=0.3615, h=0.4877
# acc_seen=0.7484, acc_unseen=0.3607, h=0.4868
# acc_seen=0.7518, acc_unseen=0.3599, h=0.4868
# acc_seen=0.7534, acc_unseen=0.3593, h=0.4866
# acc_seen=0.7498, acc_unseen=0.3590, h=0.4856
# acc_seen=0.7475, acc_unseen=0.3600, h=0.4859
# acc_seen=0.7526, acc_unseen=0.3577, h=0.4849
# GZSL Softmax:
# U->T 48.54%  S->T 66.80%  H 56.23%  Best_H [66.80% 48.54% 56.23% | Iter-2800]
# retrieval results 100%: 0.278 50%: 0.325 25%: 0.347
# Iter-[3000/66000]; loss: 12.810; kl:44.659; p_loss:0.039; rec:0.007; tc:0.823; gamma:0.003;
# Iter-[3200/66000]; loss: 12.317; kl:42.267; p_loss:0.038; rec:0.007; tc:0.821; gamma:0.003;
# acc_seen=0.0074, acc_unseen=0.5533, h=0.0145
# acc_seen=0.3406, acc_unseen=0.5692, h=0.4262
# acc_seen=0.5511, acc_unseen=0.5414, h=0.5462
# acc_seen=0.6276, acc_unseen=0.5107, h=0.5632
# acc_seen=0.6536, acc_unseen=0.5103, h=0.5732
# acc_seen=0.6852, acc_unseen=0.4961, h=0.5755
# acc_seen=0.7039, acc_unseen=0.4825, h=0.5726
# acc_seen=0.7047, acc_unseen=0.4722, h=0.5655
# acc_seen=0.7105, acc_unseen=0.4659, h=0.5628
# acc_seen=0.7158, acc_unseen=0.4586, h=0.5591
# acc_seen=0.7086, acc_unseen=0.4591, h=0.5572
# acc_seen=0.7168, acc_unseen=0.4487, h=0.5519
# acc_seen=0.7292, acc_unseen=0.4411, h=0.5497
# acc_seen=0.7321, acc_unseen=0.4316, h=0.5431
# acc_seen=0.7286, acc_unseen=0.4360, h=0.5456
# acc_seen=0.7284, acc_unseen=0.4235, h=0.5356
# acc_seen=0.7397, acc_unseen=0.4239, h=0.5389
# acc_seen=0.7342, acc_unseen=0.4266, h=0.5396
# acc_seen=0.7409, acc_unseen=0.4205, h=0.5365
# acc_seen=0.7381, acc_unseen=0.4101, h=0.5272
# acc_seen=0.7375, acc_unseen=0.4114, h=0.5282
# acc_seen=0.7395, acc_unseen=0.4111, h=0.5284
# acc_seen=0.7433, acc_unseen=0.4097, h=0.5282
# acc_seen=0.7427, acc_unseen=0.4061, h=0.5251
# acc_seen=0.7406, acc_unseen=0.4054, h=0.5240
# acc_seen=0.7417, acc_unseen=0.3998, h=0.5196
# acc_seen=0.7426, acc_unseen=0.4013, h=0.5210
# acc_seen=0.7418, acc_unseen=0.3980, h=0.5180
# acc_seen=0.7411, acc_unseen=0.4027, h=0.5218
# acc_seen=0.7456, acc_unseen=0.3949, h=0.5163
# acc_seen=0.7483, acc_unseen=0.3943, h=0.5164
# acc_seen=0.7484, acc_unseen=0.3848, h=0.5083
# acc_seen=0.7476, acc_unseen=0.3904, h=0.5129
# acc_seen=0.7492, acc_unseen=0.3919, h=0.5146
# acc_seen=0.7443, acc_unseen=0.3907, h=0.5124
# acc_seen=0.7512, acc_unseen=0.3860, h=0.5099
# acc_seen=0.7499, acc_unseen=0.3859, h=0.5095
# acc_seen=0.7442, acc_unseen=0.3859, h=0.5082
# acc_seen=0.7461, acc_unseen=0.3878, h=0.5103
# acc_seen=0.7484, acc_unseen=0.3809, h=0.5048
# acc_seen=0.7496, acc_unseen=0.3848, h=0.5085
# acc_seen=0.7522, acc_unseen=0.3807, h=0.5055
# acc_seen=0.7471, acc_unseen=0.3827, h=0.5061
# acc_seen=0.7495, acc_unseen=0.3799, h=0.5042
# acc_seen=0.7489, acc_unseen=0.3827, h=0.5065
# acc_seen=0.7542, acc_unseen=0.3769, h=0.5026
# acc_seen=0.7446, acc_unseen=0.3772, h=0.5008
# acc_seen=0.7523, acc_unseen=0.3747, h=0.5002
# acc_seen=0.7492, acc_unseen=0.3761, h=0.5008
# acc_seen=0.7503, acc_unseen=0.3793, h=0.5039
# GZSL Softmax:
# U->T 49.61%  S->T 68.52%  H 57.55%  Best_H [68.52% 49.61% 57.55% | Iter-3200]
# retrieval results 100%: 0.297 50%: 0.343 25%: 0.375
# Iter-[3400/66000]; loss: 12.384; kl:42.616; p_loss:0.038; rec:0.007; tc:0.820; gamma:0.003;
# Iter-[3600/66000]; loss: 11.758; kl:38.609; p_loss:0.037; rec:0.006; tc:0.822; gamma:0.003;
# acc_seen=0.0032, acc_unseen=0.5757, h=0.0064
# acc_seen=0.3613, acc_unseen=0.5698, h=0.4422
# acc_seen=0.5737, acc_unseen=0.5457, h=0.5594
# acc_seen=0.6317, acc_unseen=0.5250, h=0.5734
# acc_seen=0.6657, acc_unseen=0.5101, h=0.5776
# acc_seen=0.6776, acc_unseen=0.4975, h=0.5738
# acc_seen=0.6962, acc_unseen=0.4858, h=0.5723
# acc_seen=0.6973, acc_unseen=0.4731, h=0.5637
# acc_seen=0.7043, acc_unseen=0.4620, h=0.5580
# acc_seen=0.7122, acc_unseen=0.4680, h=0.5648
# acc_seen=0.7161, acc_unseen=0.4455, h=0.5493
# acc_seen=0.7187, acc_unseen=0.4421, h=0.5475
# acc_seen=0.7243, acc_unseen=0.4419, h=0.5489
# acc_seen=0.7249, acc_unseen=0.4289, h=0.5389
# acc_seen=0.7250, acc_unseen=0.4283, h=0.5385
# acc_seen=0.7286, acc_unseen=0.4264, h=0.5380
# acc_seen=0.7250, acc_unseen=0.4260, h=0.5366
# acc_seen=0.7341, acc_unseen=0.4218, h=0.5358
# acc_seen=0.7343, acc_unseen=0.4178, h=0.5326
# acc_seen=0.7346, acc_unseen=0.4160, h=0.5312
# acc_seen=0.7362, acc_unseen=0.4181, h=0.5333
# acc_seen=0.7396, acc_unseen=0.4055, h=0.5238
# acc_seen=0.7410, acc_unseen=0.4115, h=0.5292
# acc_seen=0.7419, acc_unseen=0.4061, h=0.5249
# acc_seen=0.7361, acc_unseen=0.4094, h=0.5262
# acc_seen=0.7444, acc_unseen=0.4063, h=0.5257
# acc_seen=0.7434, acc_unseen=0.3984, h=0.5188
# acc_seen=0.7440, acc_unseen=0.4065, h=0.5258
# acc_seen=0.7433, acc_unseen=0.3994, h=0.5196
# acc_seen=0.7455, acc_unseen=0.3998, h=0.5204
# acc_seen=0.7447, acc_unseen=0.3987, h=0.5194
# acc_seen=0.7465, acc_unseen=0.3963, h=0.5177
# acc_seen=0.7478, acc_unseen=0.3910, h=0.5135
# acc_seen=0.7438, acc_unseen=0.3936, h=0.5148
# acc_seen=0.7464, acc_unseen=0.3983, h=0.5194
# acc_seen=0.7424, acc_unseen=0.3957, h=0.5162
# acc_seen=0.7445, acc_unseen=0.3933, h=0.5147
# acc_seen=0.7494, acc_unseen=0.3943, h=0.5167
# acc_seen=0.7459, acc_unseen=0.3899, h=0.5121
# acc_seen=0.7478, acc_unseen=0.3950, h=0.5170
# acc_seen=0.7479, acc_unseen=0.3866, h=0.5097
# acc_seen=0.7466, acc_unseen=0.3881, h=0.5107
# acc_seen=0.7506, acc_unseen=0.3850, h=0.5090
# acc_seen=0.7486, acc_unseen=0.3894, h=0.5123
# acc_seen=0.7525, acc_unseen=0.3849, h=0.5093
# acc_seen=0.7488, acc_unseen=0.3852, h=0.5087
# acc_seen=0.7486, acc_unseen=0.3827, h=0.5065
# acc_seen=0.7474, acc_unseen=0.3828, h=0.5063
# acc_seen=0.7501, acc_unseen=0.3841, h=0.5080
# acc_seen=0.7499, acc_unseen=0.3813, h=0.5055
# GZSL Softmax:
# U->T 51.01%  S->T 66.57%  H 57.76%  Best_H [66.57% 51.01% 57.76% | Iter-3600]
# retrieval results 100%: 0.314 50%: 0.360 25%: 0.395
# Iter-[3800/66000]; loss: 11.851; kl:40.061; p_loss:0.036; rec:0.006; tc:0.815; gamma:0.003;
# Iter-[4000/66000]; loss: 11.552; kl:39.804; p_loss:0.034; rec:0.006; tc:0.818; gamma:0.004;
# acc_seen=0.0085, acc_unseen=0.5626, h=0.0167
# acc_seen=0.4104, acc_unseen=0.5753, h=0.4791
# acc_seen=0.5710, acc_unseen=0.5498, h=0.5602
# acc_seen=0.6434, acc_unseen=0.5274, h=0.5797
# acc_seen=0.6721, acc_unseen=0.5087, h=0.5791
# acc_seen=0.6818, acc_unseen=0.4970, h=0.5749
# acc_seen=0.7002, acc_unseen=0.4849, h=0.5730
# acc_seen=0.7087, acc_unseen=0.4825, h=0.5741
# acc_seen=0.7164, acc_unseen=0.4678, h=0.5660
# acc_seen=0.7219, acc_unseen=0.4716, h=0.5705
# acc_seen=0.7214, acc_unseen=0.4583, h=0.5605
# acc_seen=0.7284, acc_unseen=0.4471, h=0.5540
# acc_seen=0.7324, acc_unseen=0.4447, h=0.5534
# acc_seen=0.7311, acc_unseen=0.4446, h=0.5529
# acc_seen=0.7385, acc_unseen=0.4391, h=0.5507
# acc_seen=0.7365, acc_unseen=0.4375, h=0.5489
# acc_seen=0.7392, acc_unseen=0.4400, h=0.5517
# acc_seen=0.7449, acc_unseen=0.4301, h=0.5454
# acc_seen=0.7498, acc_unseen=0.4302, h=0.5467
# acc_seen=0.7405, acc_unseen=0.4313, h=0.5451
# acc_seen=0.7475, acc_unseen=0.4279, h=0.5442
# acc_seen=0.7500, acc_unseen=0.4206, h=0.5390
# acc_seen=0.7475, acc_unseen=0.4232, h=0.5404
# acc_seen=0.7479, acc_unseen=0.4222, h=0.5397
# acc_seen=0.7499, acc_unseen=0.4214, h=0.5396
# acc_seen=0.7517, acc_unseen=0.4179, h=0.5372
# acc_seen=0.7534, acc_unseen=0.4199, h=0.5393
# acc_seen=0.7551, acc_unseen=0.4153, h=0.5358
# acc_seen=0.7542, acc_unseen=0.4113, h=0.5323
# acc_seen=0.7531, acc_unseen=0.4147, h=0.5348
# acc_seen=0.7532, acc_unseen=0.4127, h=0.5333
# acc_seen=0.7527, acc_unseen=0.4117, h=0.5323
# acc_seen=0.7545, acc_unseen=0.4113, h=0.5324
# acc_seen=0.7614, acc_unseen=0.4071, h=0.5305
# acc_seen=0.7563, acc_unseen=0.4092, h=0.5311
# acc_seen=0.7531, acc_unseen=0.4116, h=0.5323
# acc_seen=0.7563, acc_unseen=0.4124, h=0.5338
# acc_seen=0.7570, acc_unseen=0.4073, h=0.5296
# acc_seen=0.7575, acc_unseen=0.4049, h=0.5277
# acc_seen=0.7554, acc_unseen=0.4116, h=0.5329
# acc_seen=0.7550, acc_unseen=0.4045, h=0.5268
# acc_seen=0.7575, acc_unseen=0.4017, h=0.5250
# acc_seen=0.7607, acc_unseen=0.4096, h=0.5325
# acc_seen=0.7563, acc_unseen=0.4078, h=0.5299
# acc_seen=0.7579, acc_unseen=0.4070, h=0.5296
# acc_seen=0.7614, acc_unseen=0.4056, h=0.5292
# acc_seen=0.7635, acc_unseen=0.3996, h=0.5247
# acc_seen=0.7640, acc_unseen=0.3981, h=0.5234
# acc_seen=0.7588, acc_unseen=0.4013, h=0.5249
# acc_seen=0.7602, acc_unseen=0.4015, h=0.5255
# GZSL Softmax:
# U->T 52.74%  S->T 64.34%  H 57.97%  Best_H [64.34% 52.74% 57.97% | Iter-4000]
# retrieval results 100%: 0.325 50%: 0.376 25%: 0.414
# Iter-[4200/66000]; loss: 12.490; kl:41.541; p_loss:0.037; rec:0.007; tc:0.817; gamma:0.004;
# Iter-[4400/66000]; loss: 12.000; kl:41.151; p_loss:0.037; rec:0.006; tc:0.818; gamma:0.004;
# acc_seen=0.0198, acc_unseen=0.5714, h=0.0383
# acc_seen=0.4191, acc_unseen=0.6023, h=0.4943
# acc_seen=0.5738, acc_unseen=0.5580, h=0.5658
# acc_seen=0.6531, acc_unseen=0.5345, h=0.5879
# acc_seen=0.6672, acc_unseen=0.5204, h=0.5847
# acc_seen=0.6864, acc_unseen=0.5054, h=0.5822
# acc_seen=0.6914, acc_unseen=0.4936, h=0.5760
# acc_seen=0.6999, acc_unseen=0.4830, h=0.5716
# acc_seen=0.7136, acc_unseen=0.4787, h=0.5730
# acc_seen=0.7180, acc_unseen=0.4697, h=0.5679
# acc_seen=0.7238, acc_unseen=0.4653, h=0.5665
# acc_seen=0.7294, acc_unseen=0.4625, h=0.5660
# acc_seen=0.7263, acc_unseen=0.4483, h=0.5544
# acc_seen=0.7304, acc_unseen=0.4537, h=0.5597
# acc_seen=0.7324, acc_unseen=0.4518, h=0.5588
# acc_seen=0.7355, acc_unseen=0.4386, h=0.5495
# acc_seen=0.7336, acc_unseen=0.4447, h=0.5538
# acc_seen=0.7351, acc_unseen=0.4394, h=0.5500
# acc_seen=0.7337, acc_unseen=0.4366, h=0.5474
# acc_seen=0.7414, acc_unseen=0.4380, h=0.5507
# acc_seen=0.7454, acc_unseen=0.4370, h=0.5510
# acc_seen=0.7429, acc_unseen=0.4283, h=0.5433
# acc_seen=0.7425, acc_unseen=0.4337, h=0.5476
# acc_seen=0.7403, acc_unseen=0.4271, h=0.5417
# acc_seen=0.7419, acc_unseen=0.4297, h=0.5442
# acc_seen=0.7396, acc_unseen=0.4262, h=0.5407
# acc_seen=0.7490, acc_unseen=0.4255, h=0.5427
# acc_seen=0.7434, acc_unseen=0.4236, h=0.5397
# acc_seen=0.7412, acc_unseen=0.4223, h=0.5380
# acc_seen=0.7473, acc_unseen=0.4209, h=0.5385
# acc_seen=0.7479, acc_unseen=0.4176, h=0.5360
# acc_seen=0.7494, acc_unseen=0.4202, h=0.5384
# acc_seen=0.7525, acc_unseen=0.4213, h=0.5402
# acc_seen=0.7471, acc_unseen=0.4228, h=0.5400
# acc_seen=0.7479, acc_unseen=0.4245, h=0.5416
# acc_seen=0.7514, acc_unseen=0.4177, h=0.5370
# acc_seen=0.7544, acc_unseen=0.4188, h=0.5386
# acc_seen=0.7504, acc_unseen=0.4161, h=0.5353
# acc_seen=0.7474, acc_unseen=0.4148, h=0.5335
# acc_seen=0.7522, acc_unseen=0.4167, h=0.5363
# acc_seen=0.7555, acc_unseen=0.4155, h=0.5362
# acc_seen=0.7561, acc_unseen=0.4106, h=0.5322
# acc_seen=0.7541, acc_unseen=0.4087, h=0.5301
# acc_seen=0.7581, acc_unseen=0.4153, h=0.5366
# acc_seen=0.7571, acc_unseen=0.4092, h=0.5313
# acc_seen=0.7553, acc_unseen=0.4120, h=0.5332
# acc_seen=0.7579, acc_unseen=0.4081, h=0.5305
# acc_seen=0.7527, acc_unseen=0.4125, h=0.5329
# acc_seen=0.7500, acc_unseen=0.4099, h=0.5301
# acc_seen=0.7610, acc_unseen=0.4093, h=0.5323
# GZSL Softmax:
# U->T 53.45%  S->T 65.31%  H 58.79%  Best_H [65.31% 53.45% 58.79% | Iter-4400]
# retrieval results 100%: 0.338 50%: 0.395 25%: 0.431
# Iter-[4600/66000]; loss: 11.666; kl:36.168; p_loss:0.035; rec:0.006; tc:0.818; gamma:0.004;
# Iter-[4800/66000]; loss: 10.761; kl:36.550; p_loss:0.037; rec:0.006; tc:0.822; gamma:0.004;
# acc_seen=0.0358, acc_unseen=0.5868, h=0.0674
# acc_seen=0.4068, acc_unseen=0.5775, h=0.4773
# acc_seen=0.5893, acc_unseen=0.5743, h=0.5817
# acc_seen=0.6401, acc_unseen=0.5385, h=0.5849
# acc_seen=0.6752, acc_unseen=0.5321, h=0.5952
# acc_seen=0.6922, acc_unseen=0.5085, h=0.5863
# acc_seen=0.6976, acc_unseen=0.5056, h=0.5863
# acc_seen=0.7121, acc_unseen=0.4961, h=0.5848
# acc_seen=0.7195, acc_unseen=0.4825, h=0.5776
# acc_seen=0.7184, acc_unseen=0.4816, h=0.5766
# acc_seen=0.7315, acc_unseen=0.4675, h=0.5704
# acc_seen=0.7312, acc_unseen=0.4620, h=0.5663
# acc_seen=0.7337, acc_unseen=0.4652, h=0.5694
# acc_seen=0.7388, acc_unseen=0.4536, h=0.5621
# acc_seen=0.7408, acc_unseen=0.4588, h=0.5667
# acc_seen=0.7417, acc_unseen=0.4540, h=0.5632
# acc_seen=0.7391, acc_unseen=0.4476, h=0.5575
# acc_seen=0.7438, acc_unseen=0.4472, h=0.5585
# acc_seen=0.7448, acc_unseen=0.4425, h=0.5552
# acc_seen=0.7503, acc_unseen=0.4421, h=0.5564
# acc_seen=0.7449, acc_unseen=0.4446, h=0.5569
# acc_seen=0.7431, acc_unseen=0.4457, h=0.5572
# acc_seen=0.7524, acc_unseen=0.4319, h=0.5488
# acc_seen=0.7476, acc_unseen=0.4378, h=0.5522
# acc_seen=0.7511, acc_unseen=0.4377, h=0.5531
# acc_seen=0.7499, acc_unseen=0.4354, h=0.5509
# acc_seen=0.7518, acc_unseen=0.4336, h=0.5500
# acc_seen=0.7512, acc_unseen=0.4345, h=0.5506
# acc_seen=0.7490, acc_unseen=0.4324, h=0.5483
# acc_seen=0.7504, acc_unseen=0.4241, h=0.5419
# acc_seen=0.7502, acc_unseen=0.4275, h=0.5447
# acc_seen=0.7522, acc_unseen=0.4269, h=0.5446
# acc_seen=0.7536, acc_unseen=0.4290, h=0.5467
# acc_seen=0.7547, acc_unseen=0.4266, h=0.5451
# acc_seen=0.7494, acc_unseen=0.4225, h=0.5404
# acc_seen=0.7511, acc_unseen=0.4276, h=0.5449
# acc_seen=0.7540, acc_unseen=0.4195, h=0.5391
# acc_seen=0.7536, acc_unseen=0.4208, h=0.5400
# acc_seen=0.7542, acc_unseen=0.4235, h=0.5424
# acc_seen=0.7555, acc_unseen=0.4196, h=0.5395
# acc_seen=0.7558, acc_unseen=0.4279, h=0.5464
# acc_seen=0.7577, acc_unseen=0.4166, h=0.5376
# acc_seen=0.7547, acc_unseen=0.4156, h=0.5361
# acc_seen=0.7545, acc_unseen=0.4196, h=0.5393
# acc_seen=0.7530, acc_unseen=0.4209, h=0.5400
# acc_seen=0.7603, acc_unseen=0.4160, h=0.5378
# acc_seen=0.7609, acc_unseen=0.4161, h=0.5380
# acc_seen=0.7577, acc_unseen=0.4140, h=0.5354
# acc_seen=0.7547, acc_unseen=0.4121, h=0.5331
# acc_seen=0.7616, acc_unseen=0.4163, h=0.5383
# GZSL Softmax:
# U->T 53.21%  S->T 67.52%  H 59.52%  Best_H [67.52% 53.21% 59.52% | Iter-4800]
# retrieval results 100%: 0.351 50%: 0.403 25%: 0.435
# Iter-[5000/66000]; loss: 11.835; kl:36.425; p_loss:0.033; rec:0.006; tc:0.819; gamma:0.005;
# Iter-[5200/66000]; loss: 12.610; kl:35.264; p_loss:0.034; rec:0.007; tc:0.820; gamma:0.005;
# acc_seen=0.0361, acc_unseen=0.6106, h=0.0682
# acc_seen=0.4254, acc_unseen=0.6013, h=0.4983
# acc_seen=0.5929, acc_unseen=0.5770, h=0.5848
# acc_seen=0.6482, acc_unseen=0.5437, h=0.5914
# acc_seen=0.6676, acc_unseen=0.5342, h=0.5935
# acc_seen=0.6919, acc_unseen=0.5184, h=0.5927
# acc_seen=0.6980, acc_unseen=0.5083, h=0.5883
# acc_seen=0.7196, acc_unseen=0.4927, h=0.5849
# acc_seen=0.7141, acc_unseen=0.4928, h=0.5832
# acc_seen=0.7239, acc_unseen=0.4803, h=0.5775
# acc_seen=0.7299, acc_unseen=0.4839, h=0.5819
# acc_seen=0.7269, acc_unseen=0.4792, h=0.5776
# acc_seen=0.7370, acc_unseen=0.4724, h=0.5757
# acc_seen=0.7387, acc_unseen=0.4638, h=0.5698
# acc_seen=0.7414, acc_unseen=0.4633, h=0.5703
# acc_seen=0.7406, acc_unseen=0.4670, h=0.5728
# acc_seen=0.7445, acc_unseen=0.4616, h=0.5699
# acc_seen=0.7434, acc_unseen=0.4597, h=0.5681
# acc_seen=0.7483, acc_unseen=0.4588, h=0.5688
# acc_seen=0.7495, acc_unseen=0.4536, h=0.5652
# acc_seen=0.7519, acc_unseen=0.4487, h=0.5620
# acc_seen=0.7503, acc_unseen=0.4493, h=0.5620
# acc_seen=0.7557, acc_unseen=0.4461, h=0.5610
# acc_seen=0.7531, acc_unseen=0.4490, h=0.5626
# acc_seen=0.7561, acc_unseen=0.4443, h=0.5597
# acc_seen=0.7519, acc_unseen=0.4416, h=0.5564
# acc_seen=0.7578, acc_unseen=0.4419, h=0.5582
# acc_seen=0.7559, acc_unseen=0.4408, h=0.5569
# acc_seen=0.7541, acc_unseen=0.4451, h=0.5598
# acc_seen=0.7526, acc_unseen=0.4399, h=0.5552
# acc_seen=0.7561, acc_unseen=0.4415, h=0.5574
# acc_seen=0.7571, acc_unseen=0.4401, h=0.5566
# acc_seen=0.7553, acc_unseen=0.4362, h=0.5530
# acc_seen=0.7614, acc_unseen=0.4323, h=0.5514
# acc_seen=0.7591, acc_unseen=0.4327, h=0.5512
# acc_seen=0.7562, acc_unseen=0.4377, h=0.5545
# acc_seen=0.7590, acc_unseen=0.4332, h=0.5516
# acc_seen=0.7597, acc_unseen=0.4300, h=0.5492
# acc_seen=0.7552, acc_unseen=0.4305, h=0.5484
# acc_seen=0.7620, acc_unseen=0.4317, h=0.5512
# acc_seen=0.7591, acc_unseen=0.4282, h=0.5476
# acc_seen=0.7551, acc_unseen=0.4296, h=0.5476
# acc_seen=0.7583, acc_unseen=0.4327, h=0.5510
# acc_seen=0.7611, acc_unseen=0.4268, h=0.5469
# acc_seen=0.7611, acc_unseen=0.4258, h=0.5461
# acc_seen=0.7576, acc_unseen=0.4270, h=0.5462
# acc_seen=0.7584, acc_unseen=0.4251, h=0.5448
# acc_seen=0.7605, acc_unseen=0.4224, h=0.5431
# acc_seen=0.7642, acc_unseen=0.4263, h=0.5473
# acc_seen=0.7584, acc_unseen=0.4229, h=0.5430
# GZSL Softmax:
# U->T 53.42%  S->T 66.76%  H 59.35%  Best_H [67.52% 53.21% 59.52% | Iter-4800]
# retrieval results 100%: 0.358 50%: 0.426 25%: 0.460
# Iter-[5400/66000]; loss: 11.636; kl:37.221; p_loss:0.033; rec:0.006; tc:0.821; gamma:0.005;
# Iter-[5600/66000]; loss: 11.962; kl:35.987; p_loss:0.034; rec:0.006; tc:0.821; gamma:0.005;
# acc_seen=0.0386, acc_unseen=0.6091, h=0.0726
# acc_seen=0.4427, acc_unseen=0.5910, h=0.5062
# acc_seen=0.5941, acc_unseen=0.5724, h=0.5831
# acc_seen=0.6444, acc_unseen=0.5540, h=0.5958
# acc_seen=0.6777, acc_unseen=0.5353, h=0.5982
# acc_seen=0.6942, acc_unseen=0.5264, h=0.5988
# acc_seen=0.7057, acc_unseen=0.5064, h=0.5897
# acc_seen=0.7196, acc_unseen=0.5037, h=0.5926
# acc_seen=0.7216, acc_unseen=0.4924, h=0.5854
# acc_seen=0.7285, acc_unseen=0.4956, h=0.5899
# acc_seen=0.7271, acc_unseen=0.4867, h=0.5831
# acc_seen=0.7343, acc_unseen=0.4890, h=0.5870
# acc_seen=0.7312, acc_unseen=0.4886, h=0.5858
# acc_seen=0.7361, acc_unseen=0.4740, h=0.5767
# acc_seen=0.7412, acc_unseen=0.4708, h=0.5758
# acc_seen=0.7405, acc_unseen=0.4697, h=0.5748
# acc_seen=0.7412, acc_unseen=0.4663, h=0.5725
# acc_seen=0.7393, acc_unseen=0.4655, h=0.5713
# acc_seen=0.7447, acc_unseen=0.4608, h=0.5693
# acc_seen=0.7489, acc_unseen=0.4600, h=0.5700
# acc_seen=0.7501, acc_unseen=0.4632, h=0.5728
# acc_seen=0.7457, acc_unseen=0.4558, h=0.5658
# acc_seen=0.7477, acc_unseen=0.4556, h=0.5662
# acc_seen=0.7491, acc_unseen=0.4525, h=0.5642
# acc_seen=0.7522, acc_unseen=0.4559, h=0.5677
# acc_seen=0.7527, acc_unseen=0.4503, h=0.5635
# acc_seen=0.7501, acc_unseen=0.4474, h=0.5605
# acc_seen=0.7541, acc_unseen=0.4494, h=0.5632
# acc_seen=0.7532, acc_unseen=0.4464, h=0.5606
# acc_seen=0.7517, acc_unseen=0.4418, h=0.5566
# acc_seen=0.7533, acc_unseen=0.4439, h=0.5587
# acc_seen=0.7540, acc_unseen=0.4402, h=0.5558
# acc_seen=0.7544, acc_unseen=0.4479, h=0.5621
# acc_seen=0.7549, acc_unseen=0.4392, h=0.5553
# acc_seen=0.7557, acc_unseen=0.4407, h=0.5567
# acc_seen=0.7565, acc_unseen=0.4389, h=0.5555
# acc_seen=0.7555, acc_unseen=0.4407, h=0.5567
# acc_seen=0.7562, acc_unseen=0.4430, h=0.5587
# acc_seen=0.7551, acc_unseen=0.4333, h=0.5506
# acc_seen=0.7544, acc_unseen=0.4372, h=0.5536
# acc_seen=0.7540, acc_unseen=0.4389, h=0.5548
# acc_seen=0.7592, acc_unseen=0.4343, h=0.5525
# acc_seen=0.7525, acc_unseen=0.4338, h=0.5503
# acc_seen=0.7603, acc_unseen=0.4355, h=0.5538
# acc_seen=0.7562, acc_unseen=0.4338, h=0.5513
# acc_seen=0.7589, acc_unseen=0.4331, h=0.5515
# acc_seen=0.7592, acc_unseen=0.4343, h=0.5525
# acc_seen=0.7607, acc_unseen=0.4275, h=0.5473
# acc_seen=0.7578, acc_unseen=0.4328, h=0.5509
# acc_seen=0.7617, acc_unseen=0.4274, h=0.5476
# GZSL Softmax:
# U->T 52.64%  S->T 69.42%  H 59.88%  Best_H [69.42% 52.64% 59.88% | Iter-5600]
# retrieval results 100%: 0.369 50%: 0.441 25%: 0.483
# Iter-[5800/66000]; loss: 11.087; kl:34.102; p_loss:0.030; rec:0.005; tc:0.820; gamma:0.005;
# Iter-[6000/66000]; loss: 10.394; kl:32.864; p_loss:0.029; rec:0.005; tc:0.820; gamma:0.005;
# acc_seen=0.0678, acc_unseen=0.5896, h=0.1217
# acc_seen=0.4574, acc_unseen=0.6062, h=0.5214
# acc_seen=0.5977, acc_unseen=0.5844, h=0.5909
# acc_seen=0.6542, acc_unseen=0.5479, h=0.5964
# acc_seen=0.6798, acc_unseen=0.5368, h=0.5999
# acc_seen=0.6890, acc_unseen=0.5275, h=0.5975
# acc_seen=0.7046, acc_unseen=0.5095, h=0.5914
# acc_seen=0.7172, acc_unseen=0.5112, h=0.5969
# acc_seen=0.7208, acc_unseen=0.4990, h=0.5897
# acc_seen=0.7237, acc_unseen=0.4928, h=0.5864
# acc_seen=0.7296, acc_unseen=0.4944, h=0.5894
# acc_seen=0.7313, acc_unseen=0.4931, h=0.5890
# acc_seen=0.7351, acc_unseen=0.4876, h=0.5863
# acc_seen=0.7408, acc_unseen=0.4730, h=0.5774
# acc_seen=0.7370, acc_unseen=0.4769, h=0.5791
# acc_seen=0.7401, acc_unseen=0.4722, h=0.5766
# acc_seen=0.7457, acc_unseen=0.4708, h=0.5772
# acc_seen=0.7446, acc_unseen=0.4691, h=0.5756
# acc_seen=0.7462, acc_unseen=0.4701, h=0.5768
# acc_seen=0.7445, acc_unseen=0.4667, h=0.5737
# acc_seen=0.7481, acc_unseen=0.4695, h=0.5769
# acc_seen=0.7478, acc_unseen=0.4646, h=0.5732
# acc_seen=0.7467, acc_unseen=0.4602, h=0.5694
# acc_seen=0.7524, acc_unseen=0.4617, h=0.5722
# acc_seen=0.7526, acc_unseen=0.4594, h=0.5705
# acc_seen=0.7524, acc_unseen=0.4529, h=0.5654
# acc_seen=0.7499, acc_unseen=0.4576, h=0.5684
# acc_seen=0.7490, acc_unseen=0.4553, h=0.5663
# acc_seen=0.7569, acc_unseen=0.4562, h=0.5693
# acc_seen=0.7558, acc_unseen=0.4583, h=0.5706
# acc_seen=0.7562, acc_unseen=0.4559, h=0.5689
# acc_seen=0.7551, acc_unseen=0.4536, h=0.5668
# acc_seen=0.7572, acc_unseen=0.4508, h=0.5651
# acc_seen=0.7564, acc_unseen=0.4516, h=0.5656
# acc_seen=0.7566, acc_unseen=0.4499, h=0.5643
# acc_seen=0.7592, acc_unseen=0.4492, h=0.5644
# acc_seen=0.7596, acc_unseen=0.4513, h=0.5662
# acc_seen=0.7548, acc_unseen=0.4543, h=0.5673
# acc_seen=0.7580, acc_unseen=0.4500, h=0.5647
# acc_seen=0.7565, acc_unseen=0.4483, h=0.5630
# acc_seen=0.7581, acc_unseen=0.4492, h=0.5641
# acc_seen=0.7593, acc_unseen=0.4431, h=0.5596
# acc_seen=0.7575, acc_unseen=0.4470, h=0.5622
# acc_seen=0.7616, acc_unseen=0.4431, h=0.5602
# acc_seen=0.7594, acc_unseen=0.4411, h=0.5580
# acc_seen=0.7606, acc_unseen=0.4418, h=0.5589
# acc_seen=0.7601, acc_unseen=0.4446, h=0.5610
# acc_seen=0.7595, acc_unseen=0.4416, h=0.5584
# acc_seen=0.7596, acc_unseen=0.4429, h=0.5595
# acc_seen=0.7617, acc_unseen=0.4430, h=0.5602
# GZSL Softmax:
# U->T 53.68%  S->T 67.98%  H 59.99%  Best_H [67.98% 53.68% 59.99% | Iter-6000]
# retrieval results 100%: 0.373 50%: 0.447 25%: 0.498
# Iter-[6200/66000]; loss: 10.676; kl:32.636; p_loss:0.029; rec:0.005; tc:0.821; gamma:0.006;
# Iter-[6400/66000]; loss: 10.719; kl:31.357; p_loss:0.027; rec:0.005; tc:0.822; gamma:0.006;
# acc_seen=0.0865, acc_unseen=0.6238, h=0.1520
# acc_seen=0.4738, acc_unseen=0.6138, h=0.5348
# acc_seen=0.6170, acc_unseen=0.5745, h=0.5950
# acc_seen=0.6700, acc_unseen=0.5607, h=0.6105
# acc_seen=0.6859, acc_unseen=0.5442, h=0.6069
# acc_seen=0.6943, acc_unseen=0.5331, h=0.6031
# acc_seen=0.7078, acc_unseen=0.5223, h=0.6011
# acc_seen=0.7186, acc_unseen=0.5107, h=0.5971
# acc_seen=0.7237, acc_unseen=0.5095, h=0.5980
# acc_seen=0.7308, acc_unseen=0.5094, h=0.6003
# acc_seen=0.7258, acc_unseen=0.5039, h=0.5949
# acc_seen=0.7356, acc_unseen=0.4985, h=0.5943
# acc_seen=0.7375, acc_unseen=0.4950, h=0.5924
# acc_seen=0.7385, acc_unseen=0.4927, h=0.5911
# acc_seen=0.7469, acc_unseen=0.4873, h=0.5898
# acc_seen=0.7384, acc_unseen=0.4892, h=0.5885
# acc_seen=0.7401, acc_unseen=0.4870, h=0.5874
# acc_seen=0.7446, acc_unseen=0.4792, h=0.5831
# acc_seen=0.7494, acc_unseen=0.4796, h=0.5849
# acc_seen=0.7508, acc_unseen=0.4747, h=0.5817
# acc_seen=0.7480, acc_unseen=0.4774, h=0.5828
# acc_seen=0.7507, acc_unseen=0.4731, h=0.5804
# acc_seen=0.7542, acc_unseen=0.4731, h=0.5815
# acc_seen=0.7559, acc_unseen=0.4691, h=0.5789
# acc_seen=0.7468, acc_unseen=0.4696, h=0.5767
# acc_seen=0.7496, acc_unseen=0.4689, h=0.5769
# acc_seen=0.7556, acc_unseen=0.4603, h=0.5721
# acc_seen=0.7560, acc_unseen=0.4596, h=0.5717
# acc_seen=0.7559, acc_unseen=0.4617, h=0.5732
# acc_seen=0.7505, acc_unseen=0.4652, h=0.5744
# acc_seen=0.7544, acc_unseen=0.4643, h=0.5748
# acc_seen=0.7534, acc_unseen=0.4559, h=0.5681
# acc_seen=0.7476, acc_unseen=0.4553, h=0.5659
# acc_seen=0.7511, acc_unseen=0.4599, h=0.5705
# acc_seen=0.7561, acc_unseen=0.4544, h=0.5677
# acc_seen=0.7492, acc_unseen=0.4622, h=0.5717
# acc_seen=0.7557, acc_unseen=0.4578, h=0.5702
# acc_seen=0.7579, acc_unseen=0.4552, h=0.5687
# acc_seen=0.7483, acc_unseen=0.4574, h=0.5678
# acc_seen=0.7545, acc_unseen=0.4532, h=0.5662
# acc_seen=0.7562, acc_unseen=0.4529, h=0.5665
# acc_seen=0.7536, acc_unseen=0.4518, h=0.5649
# acc_seen=0.7568, acc_unseen=0.4548, h=0.5681
# acc_seen=0.7510, acc_unseen=0.4556, h=0.5672
# acc_seen=0.7578, acc_unseen=0.4501, h=0.5647
# acc_seen=0.7565, acc_unseen=0.4478, h=0.5626
# acc_seen=0.7514, acc_unseen=0.4514, h=0.5640
# acc_seen=0.7574, acc_unseen=0.4467, h=0.5620
# acc_seen=0.7546, acc_unseen=0.4508, h=0.5644
# acc_seen=0.7560, acc_unseen=0.4514, h=0.5653
# GZSL Softmax:
# U->T 56.07%  S->T 67.00%  H 61.05%  Best_H [67.00% 56.07% 61.05% | Iter-6400]
# retrieval results 100%: 0.386 50%: 0.470 25%: 0.505
# Iter-[6600/66000]; loss: 10.831; kl:30.992; p_loss:0.028; rec:0.005; tc:0.820; gamma:0.006;
# Iter-[6800/66000]; loss: 10.835; kl:31.638; p_loss:0.026; rec:0.005; tc:0.822; gamma:0.006;
# acc_seen=0.1077, acc_unseen=0.6404, h=0.1843
# acc_seen=0.4907, acc_unseen=0.6183, h=0.5472
# acc_seen=0.6180, acc_unseen=0.5915, h=0.6044
# acc_seen=0.6630, acc_unseen=0.5573, h=0.6056
# acc_seen=0.6838, acc_unseen=0.5530, h=0.6115
# acc_seen=0.7069, acc_unseen=0.5337, h=0.6082
# acc_seen=0.7102, acc_unseen=0.5261, h=0.6045
# acc_seen=0.7189, acc_unseen=0.5232, h=0.6057
# acc_seen=0.7237, acc_unseen=0.5186, h=0.6042
# acc_seen=0.7247, acc_unseen=0.5117, h=0.5999
# acc_seen=0.7363, acc_unseen=0.4953, h=0.5922
# acc_seen=0.7355, acc_unseen=0.4949, h=0.5917
# acc_seen=0.7349, acc_unseen=0.4943, h=0.5911
# acc_seen=0.7428, acc_unseen=0.4917, h=0.5917
# acc_seen=0.7464, acc_unseen=0.4892, h=0.5910
# acc_seen=0.7393, acc_unseen=0.4841, h=0.5851
# acc_seen=0.7441, acc_unseen=0.4855, h=0.5876
# acc_seen=0.7371, acc_unseen=0.4774, h=0.5795
# acc_seen=0.7404, acc_unseen=0.4806, h=0.5829
# acc_seen=0.7436, acc_unseen=0.4784, h=0.5822
# acc_seen=0.7484, acc_unseen=0.4778, h=0.5832
# acc_seen=0.7484, acc_unseen=0.4723, h=0.5791
# acc_seen=0.7522, acc_unseen=0.4689, h=0.5777
# acc_seen=0.7504, acc_unseen=0.4724, h=0.5798
# acc_seen=0.7574, acc_unseen=0.4608, h=0.5730
# acc_seen=0.7535, acc_unseen=0.4675, h=0.5770
# acc_seen=0.7545, acc_unseen=0.4650, h=0.5754
# acc_seen=0.7548, acc_unseen=0.4695, h=0.5789
# acc_seen=0.7555, acc_unseen=0.4658, h=0.5763
# acc_seen=0.7522, acc_unseen=0.4630, h=0.5732
# acc_seen=0.7571, acc_unseen=0.4613, h=0.5733
# acc_seen=0.7532, acc_unseen=0.4627, h=0.5733
# acc_seen=0.7583, acc_unseen=0.4599, h=0.5725
# acc_seen=0.7523, acc_unseen=0.4634, h=0.5735
# acc_seen=0.7517, acc_unseen=0.4624, h=0.5726
# acc_seen=0.7612, acc_unseen=0.4589, h=0.5726
# acc_seen=0.7577, acc_unseen=0.4564, h=0.5697
# acc_seen=0.7539, acc_unseen=0.4607, h=0.5719
# acc_seen=0.7570, acc_unseen=0.4546, h=0.5681
# acc_seen=0.7542, acc_unseen=0.4577, h=0.5697
# acc_seen=0.7539, acc_unseen=0.4542, h=0.5669
# acc_seen=0.7601, acc_unseen=0.4570, h=0.5708
# acc_seen=0.7565, acc_unseen=0.4526, h=0.5663
# acc_seen=0.7529, acc_unseen=0.4532, h=0.5658
# acc_seen=0.7589, acc_unseen=0.4554, h=0.5692
# acc_seen=0.7562, acc_unseen=0.4532, h=0.5667
# acc_seen=0.7579, acc_unseen=0.4526, h=0.5667
# acc_seen=0.7595, acc_unseen=0.4492, h=0.5645
# acc_seen=0.7589, acc_unseen=0.4515, h=0.5662
# acc_seen=0.7577, acc_unseen=0.4504, h=0.5649
# GZSL Softmax:
# U->T 55.30%  S->T 68.38%  H 61.15%  Best_H [68.38% 55.30% 61.15% | Iter-6800]
# retrieval results 100%: 0.393 50%: 0.471 25%: 0.513
# Iter-[7000/66000]; loss: 12.105; kl:31.332; p_loss:0.024; rec:0.006; tc:0.822; gamma:0.006;
# Iter-[7200/66000]; loss: 10.295; kl:29.015; p_loss:0.021; rec:0.005; tc:0.823; gamma:0.006;
# acc_seen=0.1060, acc_unseen=0.6380, h=0.1817
# acc_seen=0.5209, acc_unseen=0.6210, h=0.5666
# acc_seen=0.6232, acc_unseen=0.5904, h=0.6064
# acc_seen=0.6730, acc_unseen=0.5656, h=0.6146
# acc_seen=0.7008, acc_unseen=0.5480, h=0.6150
# acc_seen=0.7084, acc_unseen=0.5402, h=0.6130
# acc_seen=0.7204, acc_unseen=0.5376, h=0.6157
# acc_seen=0.7236, acc_unseen=0.5242, h=0.6080
# acc_seen=0.7302, acc_unseen=0.5202, h=0.6076
# acc_seen=0.7318, acc_unseen=0.5122, h=0.6026
# acc_seen=0.7379, acc_unseen=0.5008, h=0.5966
# acc_seen=0.7389, acc_unseen=0.5029, h=0.5985
# acc_seen=0.7388, acc_unseen=0.4962, h=0.5937
# acc_seen=0.7402, acc_unseen=0.4924, h=0.5914
# acc_seen=0.7456, acc_unseen=0.4918, h=0.5927
# acc_seen=0.7470, acc_unseen=0.4891, h=0.5912
# acc_seen=0.7478, acc_unseen=0.4921, h=0.5936
# acc_seen=0.7495, acc_unseen=0.4857, h=0.5895
# acc_seen=0.7487, acc_unseen=0.4840, h=0.5879
# acc_seen=0.7517, acc_unseen=0.4878, h=0.5917
# acc_seen=0.7502, acc_unseen=0.4850, h=0.5892
# acc_seen=0.7561, acc_unseen=0.4764, h=0.5845
# acc_seen=0.7523, acc_unseen=0.4799, h=0.5860
# acc_seen=0.7589, acc_unseen=0.4763, h=0.5852
# acc_seen=0.7563, acc_unseen=0.4796, h=0.5869
# acc_seen=0.7588, acc_unseen=0.4743, h=0.5837
# acc_seen=0.7568, acc_unseen=0.4706, h=0.5804
# acc_seen=0.7580, acc_unseen=0.4696, h=0.5799
# acc_seen=0.7553, acc_unseen=0.4753, h=0.5834
# acc_seen=0.7535, acc_unseen=0.4736, h=0.5817
# acc_seen=0.7591, acc_unseen=0.4692, h=0.5799
# acc_seen=0.7608, acc_unseen=0.4700, h=0.5810
# acc_seen=0.7570, acc_unseen=0.4696, h=0.5797
# acc_seen=0.7612, acc_unseen=0.4653, h=0.5775
# acc_seen=0.7609, acc_unseen=0.4645, h=0.5769
# acc_seen=0.7572, acc_unseen=0.4674, h=0.5780
# acc_seen=0.7611, acc_unseen=0.4621, h=0.5751
# acc_seen=0.7581, acc_unseen=0.4641, h=0.5757
# acc_seen=0.7586, acc_unseen=0.4676, h=0.5786
# acc_seen=0.7605, acc_unseen=0.4661, h=0.5780
# acc_seen=0.7614, acc_unseen=0.4644, h=0.5769
# acc_seen=0.7570, acc_unseen=0.4635, h=0.5750
# acc_seen=0.7604, acc_unseen=0.4608, h=0.5739
# acc_seen=0.7599, acc_unseen=0.4660, h=0.5778
# acc_seen=0.7629, acc_unseen=0.4601, h=0.5740
# acc_seen=0.7575, acc_unseen=0.4622, h=0.5741
# acc_seen=0.7630, acc_unseen=0.4576, h=0.5721
# acc_seen=0.7639, acc_unseen=0.4557, h=0.5708
# acc_seen=0.7617, acc_unseen=0.4575, h=0.5717
# acc_seen=0.7631, acc_unseen=0.4628, h=0.5762
# GZSL Softmax:
# U->T 53.76%  S->T 72.04%  H 61.57%  Best_H [72.04% 53.76% 61.57% | Iter-7200]
# retrieval results 100%: 0.403 50%: 0.478 25%: 0.523
# ...
# acc_seen=0.6883, acc_unseen=0.6071, h=0.6452
# acc_seen=0.6899, acc_unseen=0.6096, h=0.6473
# acc_seen=0.6968, acc_unseen=0.6129, h=0.6522
# acc_seen=0.6269, acc_unseen=0.5622, h=0.5928
# acc_seen=0.6576, acc_unseen=0.6089, h=0.6323
# acc_seen=0.7052, acc_unseen=0.6151, h=0.6571
# acc_seen=0.7153, acc_unseen=0.6231, h=0.6660
# acc_seen=0.7266, acc_unseen=0.5931, h=0.6531
# GZSL Softmax:
# U->T 62.31%  S->T 71.53%  H 66.60%  Best_H [75.12% 63.99% 69.11% | Iter-27200]
# retrieval results 100%: 0.620 50%: 0.735 25%: 0.780
# Iter-[63800/66000]; loss: 11.137; kl:2.817; p_loss:0.035; rec:0.007; tc:0.897; gamma:0.057;
# Iter-[64000/66000]; loss: 10.425; kl:2.496; p_loss:0.036; rec:0.006; tc:0.888; gamma:0.058;
# acc_seen=0.0000, acc_unseen=0.0340, h=0.0000
# acc_seen=0.0089, acc_unseen=0.2838, h=0.0172
# acc_seen=0.0010, acc_unseen=0.1953, h=0.0019
# acc_seen=0.0038, acc_unseen=0.4300, h=0.0076
# acc_seen=0.0160, acc_unseen=0.4133, h=0.0308
# acc_seen=0.0165, acc_unseen=0.5464, h=0.0320
# acc_seen=0.0427, acc_unseen=0.5946, h=0.0797
# acc_seen=0.0634, acc_unseen=0.5634, h=0.1140
# acc_seen=0.0923, acc_unseen=0.6260, h=0.1609
# acc_seen=0.1737, acc_unseen=0.6084, h=0.2702
# acc_seen=0.2126, acc_unseen=0.6019, h=0.3142
# acc_seen=0.2394, acc_unseen=0.5474, h=0.3331
# acc_seen=0.2829, acc_unseen=0.6014, h=0.3848
# acc_seen=0.3488, acc_unseen=0.6605, h=0.4565
# acc_seen=0.3452, acc_unseen=0.6092, h=0.4407
# acc_seen=0.3755, acc_unseen=0.6104, h=0.4650
# acc_seen=0.3984, acc_unseen=0.6440, h=0.4923
# acc_seen=0.4336, acc_unseen=0.6430, h=0.5179
# acc_seen=0.4183, acc_unseen=0.6480, h=0.5084
# acc_seen=0.4696, acc_unseen=0.6407, h=0.5420
# acc_seen=0.4671, acc_unseen=0.6195, h=0.5326
# acc_seen=0.4855, acc_unseen=0.6385, h=0.5516
# acc_seen=0.5296, acc_unseen=0.6414, h=0.5801
# acc_seen=0.5501, acc_unseen=0.6242, h=0.5848
# acc_seen=0.5573, acc_unseen=0.6425, h=0.5969
# acc_seen=0.5454, acc_unseen=0.6074, h=0.5747
# acc_seen=0.5611, acc_unseen=0.6231, h=0.5905
# acc_seen=0.5868, acc_unseen=0.6305, h=0.6078
# acc_seen=0.5872, acc_unseen=0.6126, h=0.5996
# acc_seen=0.5996, acc_unseen=0.6116, h=0.6055
# acc_seen=0.6018, acc_unseen=0.6206, h=0.6111
# acc_seen=0.6257, acc_unseen=0.6292, h=0.6275
# acc_seen=0.6416, acc_unseen=0.6349, h=0.6382
# acc_seen=0.6364, acc_unseen=0.6233, h=0.6298
# acc_seen=0.3173, acc_unseen=0.2169, h=0.2577
# acc_seen=0.6083, acc_unseen=0.6315, h=0.6197
# acc_seen=0.6446, acc_unseen=0.6138, h=0.6288
# acc_seen=0.6523, acc_unseen=0.6104, h=0.6306
# acc_seen=0.6743, acc_unseen=0.6111, h=0.6412
# acc_seen=0.6870, acc_unseen=0.6140, h=0.6484
# acc_seen=0.7027, acc_unseen=0.6143, h=0.6555
# acc_seen=0.6753, acc_unseen=0.6332, h=0.6536
# acc_seen=0.6741, acc_unseen=0.6049, h=0.6376
# acc_seen=0.6979, acc_unseen=0.6070, h=0.6493
# acc_seen=0.6936, acc_unseen=0.6085, h=0.6483
# acc_seen=0.6901, acc_unseen=0.5945, h=0.6387
# acc_seen=0.6963, acc_unseen=0.6134, h=0.6523
# acc_seen=0.7128, acc_unseen=0.6027, h=0.6531
# acc_seen=0.6953, acc_unseen=0.6024, h=0.6455
# acc_seen=0.7061, acc_unseen=0.5966, h=0.6467
# GZSL Softmax:
# U->T 61.43%  S->T 70.27%  H 65.55%  Best_H [75.12% 63.99% 69.11% | Iter-27200]
# retrieval results 100%: 0.623 50%: 0.742 25%: 0.786
# Iter-[64200/66000]; loss: 10.774; kl:2.267; p_loss:0.040; rec:0.006; tc:0.883; gamma:0.058;
# Iter-[64400/66000]; loss: 11.069; kl:3.083; p_loss:0.037; rec:0.006; tc:0.896; gamma:0.058;
# acc_seen=0.0000, acc_unseen=0.0561, h=0.0000
# acc_seen=0.0000, acc_unseen=0.0320, h=0.0000
# acc_seen=0.0057, acc_unseen=0.3143, h=0.0112
# acc_seen=0.0043, acc_unseen=0.4419, h=0.0085
# acc_seen=0.0138, acc_unseen=0.4555, h=0.0268
# acc_seen=0.0300, acc_unseen=0.5012, h=0.0566
# acc_seen=0.0395, acc_unseen=0.5311, h=0.0735
# acc_seen=0.0552, acc_unseen=0.5850, h=0.1010
# acc_seen=0.0723, acc_unseen=0.5819, h=0.1287
# acc_seen=0.1463, acc_unseen=0.5949, h=0.2349
# acc_seen=0.1844, acc_unseen=0.6321, h=0.2855
# acc_seen=0.2467, acc_unseen=0.5858, h=0.3471
# acc_seen=0.2677, acc_unseen=0.6235, h=0.3746
# acc_seen=0.2929, acc_unseen=0.6397, h=0.4018
# acc_seen=0.3211, acc_unseen=0.6231, h=0.4238
# acc_seen=0.3675, acc_unseen=0.6376, h=0.4663
# acc_seen=0.3795, acc_unseen=0.6607, h=0.4821
# acc_seen=0.4251, acc_unseen=0.6231, h=0.5054
# acc_seen=0.4393, acc_unseen=0.6382, h=0.5204
# acc_seen=0.4487, acc_unseen=0.6190, h=0.5203
# acc_seen=0.4963, acc_unseen=0.6236, h=0.5527
# acc_seen=0.4958, acc_unseen=0.6332, h=0.5562
# acc_seen=0.4959, acc_unseen=0.6493, h=0.5624
# acc_seen=0.5287, acc_unseen=0.6571, h=0.5859
# acc_seen=0.5486, acc_unseen=0.6265, h=0.5850
# acc_seen=0.5744, acc_unseen=0.6372, h=0.6042
# acc_seen=0.5167, acc_unseen=0.6251, h=0.5657
# acc_seen=0.5666, acc_unseen=0.6357, h=0.5992
# acc_seen=0.4830, acc_unseen=0.5780, h=0.5263
# acc_seen=0.2705, acc_unseen=0.2047, h=0.2331
# acc_seen=0.5713, acc_unseen=0.6308, h=0.5996
# acc_seen=0.6192, acc_unseen=0.6284, h=0.6238
# acc_seen=0.6250, acc_unseen=0.6085, h=0.6167
# acc_seen=0.6433, acc_unseen=0.6275, h=0.6353
# acc_seen=0.6402, acc_unseen=0.6342, h=0.6372
# acc_seen=0.6602, acc_unseen=0.6245, h=0.6418
# acc_seen=0.6444, acc_unseen=0.6339, h=0.6391
# acc_seen=0.6589, acc_unseen=0.6218, h=0.6398
# acc_seen=0.6719, acc_unseen=0.6355, h=0.6532
# acc_seen=0.6532, acc_unseen=0.6298, h=0.6413
# acc_seen=0.6753, acc_unseen=0.6112, h=0.6416
# acc_seen=0.6720, acc_unseen=0.6075, h=0.6382
# acc_seen=0.6576, acc_unseen=0.6170, h=0.6367
# acc_seen=0.6788, acc_unseen=0.6219, h=0.6491
# acc_seen=0.6820, acc_unseen=0.6073, h=0.6425
# acc_seen=0.6936, acc_unseen=0.5961, h=0.6412
# acc_seen=0.6768, acc_unseen=0.6098, h=0.6415
# acc_seen=0.6942, acc_unseen=0.6118, h=0.6504
# acc_seen=0.6777, acc_unseen=0.6029, h=0.6381
# acc_seen=0.7015, acc_unseen=0.6146, h=0.6552
# GZSL Softmax:
# U->T 61.46%  S->T 70.15%  H 65.52%  Best_H [75.12% 63.99% 69.11% | Iter-27200]
# retrieval results 100%: 0.625 50%: 0.746 25%: 0.792
# Iter-[64600/66000]; loss: 10.337; kl:2.308; p_loss:0.035; rec:0.006; tc:0.899; gamma:0.058;
# Iter-[64800/66000]; loss: 10.580; kl:2.685; p_loss:0.036; rec:0.006; tc:0.885; gamma:0.058;
# acc_seen=0.0067, acc_unseen=0.0929, h=0.0124
# acc_seen=0.0000, acc_unseen=0.1347, h=0.0000
# acc_seen=0.0061, acc_unseen=0.3436, h=0.0120
# acc_seen=0.0038, acc_unseen=0.3510, h=0.0075
# acc_seen=0.0131, acc_unseen=0.4258, h=0.0253
# acc_seen=0.0269, acc_unseen=0.5076, h=0.0511
# acc_seen=0.0664, acc_unseen=0.5801, h=0.1192
# acc_seen=0.0908, acc_unseen=0.6141, h=0.1583
# acc_seen=0.1493, acc_unseen=0.6038, h=0.2394
# acc_seen=0.1304, acc_unseen=0.5389, h=0.2100
# acc_seen=0.1899, acc_unseen=0.6503, h=0.2940
# acc_seen=0.2757, acc_unseen=0.6492, h=0.3870
# acc_seen=0.2957, acc_unseen=0.6324, h=0.4030
# acc_seen=0.3526, acc_unseen=0.6397, h=0.4546
# acc_seen=0.3702, acc_unseen=0.6328, h=0.4671
# acc_seen=0.4230, acc_unseen=0.6470, h=0.5115
# acc_seen=0.4589, acc_unseen=0.6497, h=0.5379
# acc_seen=0.4591, acc_unseen=0.6503, h=0.5382
# acc_seen=0.4845, acc_unseen=0.6604, h=0.5589
# acc_seen=0.5058, acc_unseen=0.6386, h=0.5645
# acc_seen=0.5269, acc_unseen=0.6525, h=0.5830
# acc_seen=0.4799, acc_unseen=0.5783, h=0.5245
# acc_seen=0.4688, acc_unseen=0.6024, h=0.5273
# acc_seen=0.5584, acc_unseen=0.6413, h=0.5970
# acc_seen=0.5683, acc_unseen=0.6542, h=0.6082
# acc_seen=0.5747, acc_unseen=0.6488, h=0.6095
# acc_seen=0.3253, acc_unseen=0.5109, h=0.3975
# acc_seen=0.4289, acc_unseen=0.5131, h=0.4673
# acc_seen=0.6319, acc_unseen=0.6451, h=0.6384
# acc_seen=0.6213, acc_unseen=0.6407, h=0.6308
# acc_seen=0.6272, acc_unseen=0.6411, h=0.6341
# acc_seen=0.6615, acc_unseen=0.6379, h=0.6495
# acc_seen=0.6439, acc_unseen=0.6310, h=0.6374
# acc_seen=0.6728, acc_unseen=0.6398, h=0.6559
# acc_seen=0.6669, acc_unseen=0.6146, h=0.6397
# acc_seen=0.6720, acc_unseen=0.6232, h=0.6467
# acc_seen=0.6935, acc_unseen=0.6202, h=0.6548
# acc_seen=0.6987, acc_unseen=0.6356, h=0.6657
# acc_seen=0.6744, acc_unseen=0.6403, h=0.6569
# acc_seen=0.6705, acc_unseen=0.6256, h=0.6473
# acc_seen=0.5988, acc_unseen=0.5565, h=0.5769
# acc_seen=0.6767, acc_unseen=0.6145, h=0.6441
# acc_seen=0.7010, acc_unseen=0.6039, h=0.6489
# acc_seen=0.7246, acc_unseen=0.6073, h=0.6608
# acc_seen=0.4832, acc_unseen=0.4512, h=0.4666
# acc_seen=0.6354, acc_unseen=0.5672, h=0.5993
# acc_seen=0.7225, acc_unseen=0.6026, h=0.6571
# acc_seen=0.7211, acc_unseen=0.6093, h=0.6605
# acc_seen=0.7240, acc_unseen=0.6095, h=0.6619
# acc_seen=0.7361, acc_unseen=0.5891, h=0.6544
# GZSL Softmax:
# U->T 63.56%  S->T 69.87%  H 66.57%  Best_H [75.12% 63.99% 69.11% | Iter-27200]
# retrieval results 100%: 0.632 50%: 0.747 25%: 0.805
# Iter-[65000/66000]; loss: 11.348; kl:2.741; p_loss:0.036; rec:0.007; tc:0.872; gamma:0.059;
# Iter-[65200/66000]; loss: 10.637; kl:2.509; p_loss:0.039; rec:0.007; tc:0.876; gamma:0.059;
# acc_seen=0.0047, acc_unseen=0.0521, h=0.0086
# acc_seen=0.0075, acc_unseen=0.1784, h=0.0145
# acc_seen=0.0060, acc_unseen=0.4260, h=0.0118
# acc_seen=0.0149, acc_unseen=0.5179, h=0.0290
# acc_seen=0.0271, acc_unseen=0.5522, h=0.0517
# acc_seen=0.0424, acc_unseen=0.4787, h=0.0780
# acc_seen=0.0571, acc_unseen=0.6261, h=0.1047
# acc_seen=0.1409, acc_unseen=0.6233, h=0.2299
# acc_seen=0.1661, acc_unseen=0.6029, h=0.2605
# acc_seen=0.2430, acc_unseen=0.6415, h=0.3525
# acc_seen=0.2681, acc_unseen=0.6672, h=0.3825
# acc_seen=0.3183, acc_unseen=0.6362, h=0.4243
# acc_seen=0.3699, acc_unseen=0.6238, h=0.4644
# acc_seen=0.3606, acc_unseen=0.6418, h=0.4617
# acc_seen=0.4337, acc_unseen=0.6633, h=0.5245
# acc_seen=0.4473, acc_unseen=0.6603, h=0.5334
# acc_seen=0.4427, acc_unseen=0.6631, h=0.5309
# acc_seen=0.4609, acc_unseen=0.6676, h=0.5454
# acc_seen=0.4535, acc_unseen=0.6132, h=0.5214
# acc_seen=0.5032, acc_unseen=0.6716, h=0.5753
# acc_seen=0.5235, acc_unseen=0.6583, h=0.5832
# acc_seen=0.5666, acc_unseen=0.6625, h=0.6108
# acc_seen=0.5673, acc_unseen=0.6615, h=0.6108
# acc_seen=0.5735, acc_unseen=0.6541, h=0.6112
# acc_seen=0.6014, acc_unseen=0.6455, h=0.6226
# acc_seen=0.6006, acc_unseen=0.6467, h=0.6228
# acc_seen=0.5518, acc_unseen=0.6416, h=0.5933
# acc_seen=0.2865, acc_unseen=0.3207, h=0.3026
# acc_seen=0.6003, acc_unseen=0.6459, h=0.6222
# acc_seen=0.6233, acc_unseen=0.6401, h=0.6316
# acc_seen=0.6586, acc_unseen=0.6431, h=0.6507
# acc_seen=0.6808, acc_unseen=0.6292, h=0.6539
# acc_seen=0.6643, acc_unseen=0.6345, h=0.6491
# acc_seen=0.6872, acc_unseen=0.6241, h=0.6541
# acc_seen=0.6833, acc_unseen=0.6195, h=0.6499
# acc_seen=0.6789, acc_unseen=0.6330, h=0.6551
# acc_seen=0.6786, acc_unseen=0.6186, h=0.6472
# acc_seen=0.6865, acc_unseen=0.6347, h=0.6595
# acc_seen=0.7013, acc_unseen=0.6263, h=0.6617
# acc_seen=0.7070, acc_unseen=0.6225, h=0.6621
# acc_seen=0.7052, acc_unseen=0.6078, h=0.6529
# acc_seen=0.7063, acc_unseen=0.6276, h=0.6646
# acc_seen=0.7131, acc_unseen=0.6130, h=0.6593
# acc_seen=0.7275, acc_unseen=0.6146, h=0.6663
# acc_seen=0.7033, acc_unseen=0.6183, h=0.6580
# acc_seen=0.7220, acc_unseen=0.6092, h=0.6608
# acc_seen=0.1161, acc_unseen=0.1412, h=0.1274
# acc_seen=0.5187, acc_unseen=0.5685, h=0.5424
# acc_seen=0.6985, acc_unseen=0.5982, h=0.6445
# acc_seen=0.7069, acc_unseen=0.5975, h=0.6476
# GZSL Softmax:
# U->T 61.46%  S->T 72.75%  H 66.63%  Best_H [75.12% 63.99% 69.11% | Iter-27200]
# retrieval results 100%: 0.628 50%: 0.742 25%: 0.797
# Iter-[65400/66000]; loss: 10.937; kl:2.597; p_loss:0.038; rec:0.007; tc:0.863; gamma:0.059;
# Iter-[65600/66000]; loss: 10.622; kl:2.401; p_loss:0.036; rec:0.007; tc:0.855; gamma:0.059;
# acc_seen=0.0067, acc_unseen=0.0200, h=0.0100
# acc_seen=0.0000, acc_unseen=0.1375, h=0.0000
# acc_seen=0.0010, acc_unseen=0.3241, h=0.0019
# acc_seen=0.0133, acc_unseen=0.2151, h=0.0251
# acc_seen=0.0252, acc_unseen=0.5197, h=0.0481
# acc_seen=0.0318, acc_unseen=0.4178, h=0.0590
# acc_seen=0.0125, acc_unseen=0.5414, h=0.0244
# acc_seen=0.0860, acc_unseen=0.5154, h=0.1474
# acc_seen=0.1106, acc_unseen=0.6478, h=0.1889
# acc_seen=0.1286, acc_unseen=0.5781, h=0.2103
# acc_seen=0.1494, acc_unseen=0.6117, h=0.2402
# acc_seen=0.1741, acc_unseen=0.6332, h=0.2731
# acc_seen=0.2138, acc_unseen=0.6195, h=0.3179
# acc_seen=0.2874, acc_unseen=0.6598, h=0.4004
# acc_seen=0.2846, acc_unseen=0.6321, h=0.3925
# acc_seen=0.3237, acc_unseen=0.6329, h=0.4284
# acc_seen=0.3744, acc_unseen=0.6460, h=0.4740
# acc_seen=0.4000, acc_unseen=0.6410, h=0.4926
# acc_seen=0.4347, acc_unseen=0.6205, h=0.5112
# acc_seen=0.4223, acc_unseen=0.6447, h=0.5103
# acc_seen=0.4414, acc_unseen=0.6315, h=0.5196
# acc_seen=0.5013, acc_unseen=0.6247, h=0.5562
# acc_seen=0.5184, acc_unseen=0.6607, h=0.5810
# acc_seen=0.4538, acc_unseen=0.6002, h=0.5169
# acc_seen=0.1965, acc_unseen=0.5460, h=0.2890
# acc_seen=0.5202, acc_unseen=0.6371, h=0.5728
# acc_seen=0.5519, acc_unseen=0.6321, h=0.5893
# acc_seen=0.1654, acc_unseen=0.4510, h=0.2421
# acc_seen=0.5805, acc_unseen=0.6253, h=0.6020
# acc_seen=0.5899, acc_unseen=0.6424, h=0.6150
# acc_seen=0.5976, acc_unseen=0.6425, h=0.6192
# acc_seen=0.6032, acc_unseen=0.6426, h=0.6223
# acc_seen=0.6061, acc_unseen=0.6409, h=0.6230
# acc_seen=0.6246, acc_unseen=0.6344, h=0.6295
# acc_seen=0.6182, acc_unseen=0.6500, h=0.6337
# acc_seen=0.4140, acc_unseen=0.4365, h=0.4249
# acc_seen=0.5832, acc_unseen=0.6330, h=0.6071
# acc_seen=0.6397, acc_unseen=0.6437, h=0.6417
# acc_seen=0.6600, acc_unseen=0.6218, h=0.6403
# acc_seen=0.6758, acc_unseen=0.6037, h=0.6377
# acc_seen=0.6571, acc_unseen=0.6356, h=0.6461
# acc_seen=0.6741, acc_unseen=0.5817, h=0.6245
# acc_seen=0.6714, acc_unseen=0.6260, h=0.6479
# acc_seen=0.6892, acc_unseen=0.6091, h=0.6467
# acc_seen=0.6791, acc_unseen=0.6117, h=0.6437
# acc_seen=0.6677, acc_unseen=0.6283, h=0.6474
# acc_seen=0.6823, acc_unseen=0.5952, h=0.6358
# acc_seen=0.6898, acc_unseen=0.6120, h=0.6486
# acc_seen=0.7019, acc_unseen=0.6110, h=0.6533
# acc_seen=0.7062, acc_unseen=0.6007, h=0.6492
# GZSL Softmax:
# U->T 61.10%  S->T 70.19%  H 65.33%  Best_H [75.12% 63.99% 69.11% | Iter-27200]
# retrieval results 100%: 0.633 50%: 0.750 25%: 0.799
# Iter-[65800/66000]; loss: 10.236; kl:2.529; p_loss:0.038; rec:0.006; tc:0.858; gamma:0.059;
# Iter-[66000/66000]; loss: 9.965; kl:2.325; p_loss:0.041; rec:0.006; tc:0.867; gamma:0.059;
# acc_seen=0.0012, acc_unseen=0.0558, h=0.0023
# acc_seen=0.0000, acc_unseen=0.2262, h=0.0000
# acc_seen=0.0024, acc_unseen=0.3784, h=0.0047
# acc_seen=0.0012, acc_unseen=0.3866, h=0.0024
# acc_seen=0.0184, acc_unseen=0.5260, h=0.0355
# acc_seen=0.0268, acc_unseen=0.5085, h=0.0509
# acc_seen=0.0340, acc_unseen=0.5093, h=0.0637
# acc_seen=0.0785, acc_unseen=0.5208, h=0.1365
# acc_seen=0.1248, acc_unseen=0.6032, h=0.2068
# acc_seen=0.1825, acc_unseen=0.6280, h=0.2828
# acc_seen=0.1671, acc_unseen=0.6394, h=0.2649
# acc_seen=0.2338, acc_unseen=0.6137, h=0.3386
# acc_seen=0.2912, acc_unseen=0.6311, h=0.3985
# acc_seen=0.3025, acc_unseen=0.6489, h=0.4126
# acc_seen=0.3267, acc_unseen=0.6099, h=0.4255
# acc_seen=0.3510, acc_unseen=0.6280, h=0.4503
# acc_seen=0.3952, acc_unseen=0.6276, h=0.4850
# acc_seen=0.4052, acc_unseen=0.6509, h=0.4995
# acc_seen=0.4414, acc_unseen=0.6595, h=0.5288
# acc_seen=0.4271, acc_unseen=0.6668, h=0.5207
# acc_seen=0.4862, acc_unseen=0.6496, h=0.5562
# acc_seen=0.5278, acc_unseen=0.6519, h=0.5833
# acc_seen=0.4949, acc_unseen=0.6516, h=0.5625
# acc_seen=0.5259, acc_unseen=0.6538, h=0.5829
# acc_seen=0.5431, acc_unseen=0.6261, h=0.5816
# acc_seen=0.5451, acc_unseen=0.6354, h=0.5868
# acc_seen=0.5192, acc_unseen=0.6305, h=0.5695
# acc_seen=0.5837, acc_unseen=0.6448, h=0.6127
# acc_seen=0.5897, acc_unseen=0.6330, h=0.6106
# acc_seen=0.6041, acc_unseen=0.6414, h=0.6222
# acc_seen=0.5841, acc_unseen=0.6350, h=0.6085
# acc_seen=0.3375, acc_unseen=0.4868, h=0.3986
# acc_seen=0.3623, acc_unseen=0.4169, h=0.3877
# acc_seen=0.6001, acc_unseen=0.6449, h=0.6217
# acc_seen=0.6282, acc_unseen=0.6415, h=0.6348
# acc_seen=0.6334, acc_unseen=0.6396, h=0.6365
# acc_seen=0.6410, acc_unseen=0.6328, h=0.6369
# acc_seen=0.6535, acc_unseen=0.6368, h=0.6450
# acc_seen=0.6416, acc_unseen=0.6420, h=0.6418
# acc_seen=0.6475, acc_unseen=0.6345, h=0.6409
# acc_seen=0.6617, acc_unseen=0.6226, h=0.6416
# acc_seen=0.6686, acc_unseen=0.6206, h=0.6437
# acc_seen=0.6946, acc_unseen=0.6294, h=0.6604
# acc_seen=0.6710, acc_unseen=0.6387, h=0.6545
# acc_seen=0.6945, acc_unseen=0.6205, h=0.6554
# acc_seen=0.6835, acc_unseen=0.6289, h=0.6551
# acc_seen=0.6937, acc_unseen=0.6204, h=0.6550
# acc_seen=0.6909, acc_unseen=0.6302, h=0.6592
# acc_seen=0.7053, acc_unseen=0.6237, h=0.6620
# acc_seen=0.7185, acc_unseen=0.6136, h=0.6619
# GZSL Softmax:
# U->T 62.37%  S->T 70.53%  H 66.20%  Best_H [75.12% 63.99% 69.11% | Iter-27200]
# retrieval results 100%: 0.631 50%: 0.743 25%: 0.785

# %% [markdown]
# # Results
#
# AWA2_finetune-False_wd-1e-06_b-1_g-0.5_lr-3e-05_sd-1024_dis-0.3_nS-5000_nZ-20_bs-64
# ------------------------------------------------------------------------------------ (Without Fine-tuning)
# Paper:
# unseen: 64.6, seen: 73.6, H: 68.8
#
#
# Original implementation:
# H = 68.8 %
#
#
# My implementation:
# U->T 56.26%  S->T 77.39%  H 65.16%  Best_H [73.52% 64.20% 68.55% | Iter-70300]
# retrieval results 100%: 0.435 50%: 0.524 25%: 0.594
#
# Best accuracy (unseen: 73.52, seen: 64.20, H:68.55)
#
#
# AWA2_finetune-True_wd-3e-07_b-1_g-0.5_lr-3e-05_sd-312_dis-0.3_nS-1800_nZ-20_bs-64
# --------------------------------------------------------------------------------- (With Fine-tuning)
# Paper:
# unseen: 69.6, seen: 78.2, H: 73.7
#
#
# Original implementation:
# H = 73.7 %
#
#
# My implementation:
# Iter-[55000/55050]; loss: 11.271; kl:0.807; p_loss:0.001; rec:0.023; tc:0.000; gamma:0.149;
# U->T 55.02%  S->T 84.10%  H 66.52%  Best_H [81.61% 65.53% 72.69% | Iter-35100]
# retrieval results 100%: 0.610 50%: 0.674 25%: 0.713
#
# Best accuracy (unseen: 81.61, seen: 65.53, H:72.69)
#
#
# CUB_finetune-False_wd-1e-08_b-0.003_g-5_lr-0.0001_sd-2048_dis-0.3_nS-1000_nZ-20_bs-64
# -------------------------------------------------------------------------------------- (Without Fine-tuning)
# Paper:
# unseen: 59.9, seen: 66.4, H: 63.0
#
#
# Original implementation:
# H = 54.89 %
#
#
# My implementation:
# Iter-[66000/66000]; loss: 9.923; kl:2.064; p_loss:0.000; rec:0.005; tc:0.832; gamma:0.059;
# U->T 46.05%  S->T 53.49%  H 49.49%  Best_H [56.67% 52.07% 54.27% | Iter-23200]
# retrieval results 100%: 0.436 50%: 0.532 25%: 0.578
#
# Best accuracy (unseen: 56.67, seen:52.07, H: 54.27)
#
#
# --------------------------------------------------------------------------------- (With Fine-tuning)
# Paper:
# unseen: 73.0, seen: 77.5, H: 75.1
#
# Original implementation:
# H = 70.56 %
#
# My implementation:
# Iter-[66000/66000]; loss: 9.965; kl:2.325; p_loss:0.041; rec:0.006; tc:0.867; gamma:0.059;
# U->T 62.37%  S->T 70.53%  H 66.20%  Best_H [75.12% 63.99% 69.11% | Iter-27200]
# retrieval results 100%: 0.631 50%: 0.743 25%: 0.785
#
# Best accuracy (unseen: , seen: , H: )
